# %%
import torch
import torch.nn.functional as F
from torch import nn
from torch_geometric.nn import GraphConv, global_mean_pool
import torch.distributed as dist
from datetime import timedelta
from torch.utils.data.distributed import DistributedSampler
from torch.utils.data import Subset, SubsetRandomSampler
from torch.amp import GradScaler, autocast
from sklearn.neighbors import kneighbors_graph
from torch_geometric.nn import GraphConv, global_mean_pool
from torch_geometric.data import Data, Dataset
from torch_geometric.data.data import BaseData
from torch_geometric.loader import DataLoader
from torch_geometric.utils import add_self_loops
from torch.nn.parallel import DistributedDataParallel as DDP
from sklearn.metrics import precision_score, accuracy_score, confusion_matrix, classification_report,roc_auc_score, roc_curve, auc
from sklearn.utils.class_weight import compute_class_weight
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import StratifiedKFold
from GNN_model_utils import *
import optuna
import copy
import torch.multiprocessing as mp

# %%
class GatedAttentionWithInstanceClassifier(nn.Module):
    """
    A variant that computes instance-level logits + an attention weighting,
    then aggregates instance logits to produce a slide-level prediction.
    """
    def __init__(self, input_dim, hidden_dim, num_classes):
        super().__init__()
        # For gating-based attention
        self.w_h = nn.Linear(input_dim, hidden_dim, bias=True)
        self.w_g = nn.Linear(input_dim, hidden_dim, bias=True)
        self.w_a = nn.Linear(hidden_dim, 1, bias=False)
        
        # Instance-level classifier
        self.instance_classifier = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, num_classes)  # Per-tile logits
        )

    def forward(self, x, batch=None):
        """
        Args:
            x: [N, in_dim] tile embeddings
            batch: [N], which slide each tile belongs to
        Returns:
            slide_logits: [num_slides_in_batch, num_classes]
            instance_logits: [N, num_classes]
            att_weights: [N], attention weight per tile
        """
        if batch is None:
            batch = torch.zeros(x.size(0), dtype=torch.long, device=x.device)
        
        # 1) Per-tile (instance) logits
        instance_logits = self.instance_classifier(x)  # shape [N, num_classes]
        
        # 2) Compute gated attention scores
        h = torch.tanh(self.w_h(x))      # [N, hidden_dim]
        g = torch.sigmoid(self.w_g(x))   # [N, hidden_dim]
        alpha_logits = self.w_a(h * g).squeeze(-1)  # shape [N]
        
        # 3) Aggregate instance logits -> slide logits
        unique_graph_ids = batch.unique()
        slide_logits_list = []
        att_weights_list = torch.zeros_like(alpha_logits)

        for gid in unique_graph_ids:
            mask = (batch == gid)
            alpha_g = alpha_logits[mask]         # shape [n_tiles_in_slide]
            inst_logits_g = instance_logits[mask]  # [n_tiles_in_slide, num_classes]
            
            # Normalize attention weights within this slide
            alpha_g_softmax = F.softmax(alpha_g, dim=0)
            alpha_g_softmax = alpha_g_softmax.to(att_weights_list.dtype)  
            att_weights_list[mask] = alpha_g_softmax

            # Weighted sum of instance logits => slide-level logit
            slide_logit = torch.sum(alpha_g_softmax.unsqueeze(1) * inst_logits_g, dim=0)
            slide_logits_list.append(slide_logit.unsqueeze(0))

        slide_logits = torch.cat(slide_logits_list, dim=0)  # [num_slides_in_batch, num_classes]
        
        return slide_logits, instance_logits, att_weights_list

# %%
# The GNN Model
class SlideGNN_AdvancedMIL(nn.Module):
    def __init__(self, input_dim=1024, hidden_dim=256, num_classes=2,num_layers=3,dropout=0.3):
        super().__init__()

        # Initialize a ModuleList to hold your GraphConv layers
        self.convs = nn.ModuleList()

        # Add the first layer (input layer)
        self.convs.append(GraphConv(input_dim, hidden_dim))

        # Add intermediate layers
        for _ in range(num_layers - 2):
            self.convs.append(GraphConv(hidden_dim, hidden_dim))

        # Add the last layer
        self.convs.append(GraphConv(hidden_dim, hidden_dim))

        # Store dropout
        self.dropout = dropout

        # Batch normalization layers
        self.bns = torch.nn.ModuleList([nn.BatchNorm1d(hidden_dim) for _ in range(num_layers)])

        # Attention-based pooling for slide-level embedding
        self.mil_pool = GatedAttentionWithInstanceClassifier(
            input_dim=hidden_dim,
            hidden_dim=hidden_dim,
            num_classes=num_classes
        )

        # Final classification from the pooled slide-level embedding
        self.classifier = nn.Linear(hidden_dim, num_classes)


    def forward(self, x, edge_index, batch):
        """
        x: Node features [num_nodes, in_channels]
        edge_index: Graph connectivity [2, num_edges] 
        batch: Node-to-graph assignment [num_nodes]
        """

        # Pass through each graph convolutional layer
        for i, (conv, bn) in enumerate(zip(self.convs, self.bns)):
            x = conv(x, edge_index)
            x = bn(x)
            x = F.relu(x)
            x = F.dropout(x, p=self.dropout, training=self.training)

        # MIL aggregator
        slide_logits, tile_logits, att_weights = self.mil_pool(x, batch)

        return slide_logits, tile_logits, att_weights

# %%
def train(model, train_loader, optimizer, criterion, device):
    model.train()
    scaler = GradScaler()
    train_loss = 0.0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        with autocast(device_type='cuda', dtype=torch.float16):
            # Forward pass (in mixed-precision)
            slide_logits, _, _= model(data.x, data.edge_index, data.batch)
            
            # Suppose we only have slide-level labels
            loss = criterion(slide_logits, data.y)

        # Backward pass with scaled gradients
        scaler.scale(loss).backward()
        
        # Step with the optimizer using the scaler
        scaler.step(optimizer)
        scaler.update()
        train_loss += loss.item()
    return train_loss / len(train_loader)
   

def test(model,test_loader,device):
    model.eval()
    slide_preds, slide_labels, slide_score, tile_preds, tile_score, tile_batch = [],[], [], [], [], []
    with torch.no_grad():
        for data in test_loader:
            data = data.to(device)
            slide_logits, tile_logits, att_weights = model(data.x, data.edge_index, data.batch)
            
            # ---------- Slide-level ----------
            # Slide-level predictions
            s_preds = slide_logits.argmax(dim=1)
            s_score = F.softmax(slide_logits, dim=1)
            slide_preds.extend(s_preds.cpu().numpy())
            slide_score.extend(s_score.cpu().numpy())
            slide_labels.extend(data.y.cpu().numpy())

            # ---------- Tile-level ----------
            # Convert tile_logits to probabilities
            t_preds = tile_logits.argmax(dim=1)
            t_score = F.softmax(tile_logits, dim=1)

            #t_preds = att_weights.argmax(dim=1)
            tile_preds.append(t_preds.cpu())
            tile_score.append(t_score.cpu())
            tile_batch.append(data.batch.cpu())

    # Concatenate tile-level outputs across all batches
    tile_preds = torch.cat(tile_preds, dim=0).numpy()
    tile_score = torch.cat(tile_score, dim=0).numpy()  # shape [TotalTiles, num_classes]
    tile_batch = torch.cat(tile_batch, dim=0).numpy()    # shape [TotalTiles]

    # Slide-level accuracy
    slide_accuracy = accuracy_score(slide_labels, slide_preds)
    return slide_accuracy, slide_score, slide_preds, slide_labels, tile_score, tile_preds, tile_batch

# %%
def setup_distributed_environment():
    if 'SLURM_NODELIST' in os.environ:
        master_node = os.popen(f"scontrol show hostnames {os.environ['SLURM_NODELIST']}").read().splitlines()[0]
        os.environ['MASTER_ADDR'] = master_node
    else:
        os.environ['MASTER_ADDR'] = '127.0.0.1'

    # Dynamically set MASTER_PORT if not set
    os.environ.setdefault("MASTER_PORT", str(29500 + int(os.environ.get("SLURM_PROCID", 0))))

    # SLURM-specific rank and world size
    #world_size = int(os.environ.get('WORLD_SIZE', os.environ.get('SLURM_NTASKS')))
    #rank =int(os.environ.get('RANK', os.environ.get('SLURM_PROCID')))
    #local_rank = int(os.environ.get('SLURM_LOCALID', rank % torch.cuda.device_count()))
    #local_rank = int(os.environ.get('LOCAL_RANK', os.environ.get('SLURM_LOCALID')))
    #return world_size,rank,local_rank

# %%
def run(world_size: int, rank: int, graph_dataset,sample_names,label_encoder):
    # Will query the runtime environment for `MASTER_ADDR` and `MASTER_PORT`.
    # Make sure, those are set!
    os.environ["MASTER_ADDR"] = os.popen(f"scontrol show hostnames {os.environ['SLURM_NODELIST']}").read().splitlines()[0]
    os.environ.setdefault("MASTER_PORT", str(29500 + int(os.environ.get("SLURM_PROCID", 0))))
       
    #print(f"Initializing process group: Rank={rank}, World Size={world_size}, Local Rank={local_rank}")
    dist.init_process_group('nccl', world_size=world_size, rank=rank)
    print(f"Process group initialized: Rank={rank}")


    # Move to device for faster feature fetch.
    #data = data.to(local_rank, 'x', 'y')

    folds = stratified_kfold_split(graph_dataset,  n_splits=5)
   
    for fold_idx, (train_idx, val_idx) in enumerate(folds):
        # Create a directory for this fold
        fold_dir = os.path.join(outdir, f"result_{fold_idx + 1}")
        os.makedirs(fold_dir, exist_ok=True)  # Create folder if it doesn't exist
        if rank == 0:
            print(f"  Training samples: {len(train_idx)}")
            print(f"  Validation samples: {len(val_idx)}")

        # Split dataset
        train_dataset = Subset(graph_dataset, train_idx)
        test_dataset = Subset(graph_dataset, val_idx)

        print(f"Rank={rank}, train_data:{len(train_dataset)}, test_data:{len(test_dataset)}")

        # Use DistributedSampler
        train_sampler = torch.utils.data.DistributedSampler(train_dataset, num_replicas=world_size, rank=rank, shuffle=True)
        test_sampler = torch.utils.data.DistributedSampler(test_dataset, num_replicas=world_size, rank=rank, shuffle=False)

        train_loader = DataLoader(train_dataset, batch_size=64, sampler=train_sampler)

        if rank == 0:
            test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)


        # Validate data loaders
        if rank == 0:
            print("Checking train loader...")
            check_batches(train_loader)
            if rank == 0:
                print("Checking validation loader...")
                check_batches(test_loader)

        # Initialize model
        model = SlideGNN_AdvancedMIL(input_dim=1024, hidden_dim=512, num_classes=4,num_layers=3, dropout=0.3).to(rank)
        model = DDP(model, device_ids=[rank])

        # Calculate class weights
        class_weights = calculate_class_weights_from_graph(train_dataset, device=rank)

        # Use CrossEntropyLoss with class weights
        criterion = nn.CrossEntropyLoss(weight=class_weights).to(rank)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

        # Train and evaluate
        for epoch in range(1, 101):
            train_loss = train(model, train_loader, optimizer, criterion, device=rank)
            dist.barrier()

            if rank == 0 and epoch % 5 == 0:
                slide_accuracy, slide_score, slide_preds, slide_labels, tile_score, tile_preds, tile_batch = test(model,test_loader, device=rank)
            dist.barrier()

            if rank == 0:
                print(f'Epoch: {epoch:03d}, Train Loss: {train_loss:.4f}, Accuracy:{slide_accuracy:.4f}')

                # Save model for this fold
                model_path = os.path.join(fold_dir, "GNN_ViT_model.pth")
                torch.save(model.state_dict(), model_path)
                print(f"Model for Fold {fold_idx + 1} saved at {model_path}")

                # Save slide results for this fold in a text file
                save_results_to_text(sample_names, val_idx, slide_labels, slide_preds, slide_score, label_encoder, rank, outdir = fold_dir)
            
                # Save tile predictions to an .npz file
                save_tile_results(tile_preds, tile_score, tile_batch, val_idx, sample_names, rank, output_dir = fold_dir)

        dist.barrier()

    dist.destroy_process_group()

# %%
world_size = torch.cuda.device_count()
print(f"world count:{wold_size}")

# %%
outdir="GNN_modle_Malignant_5FCross_multiGPU_old"
os.makedirs(outdir, exist_ok=True)

# %%
# old data
slide_features=np.load("../features/NCI_CBTN_GP34_features.npy", allow_pickle=True)
slide_classes=pd.read_csv("../features/NCI_CBTN_GP34_Malignant&Myeloid_Cellstate_classes.csv",index_col=0)

# %%
## load NCI CBTN Group 3 and 4 features and classes
slide_features=np.load("/data/NCI_LP/pediatric_Data/Medulloblastoma//NCI_CBTN_GP34_features.npy", allow_pickle=True)
slide_classes=pd.read_csv("/data/NCI_LP/pediatric_Data/Medulloblastoma/NCI_CBTN_MB34_320Samples_metadata_reorder.csv",index_col=0)

# %%
# Seperate sample names and image tile level features
sample_names, features = extract_sample_names_and_features(slide_features)

# Scale the features
scaled_features = scale_tile_features(features)

# Encode the target classes
slide_classes=slide_classes["Malignant.Cluster"]
label_encoder = LabelEncoder()
y_labels = label_encoder.fit_transform(slide_classes)

# creating graph data from tile level featutes
graph_dataset = TileGraphDataset(scaled_features, y_labels, k=5)

# %%
folds = stratified_kfold_split(graph_dataset,  n_splits=5)
# Out:
# Number of labels: 321:
#   Training samples: 256
#   Validation samples: 65
# ------------------------------
#   Training samples: 257
#   Validation samples: 64
# ------------------------------
#   Training samples: 257
#   Validation samples: 64
# ------------------------------
#   Training samples: 257
#   Validation samples: 64
# ------------------------------
#   Training samples: 257
#   Validation samples: 64
# ------------------------------

# %%
device = (torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu'))
for fold_idx, (train_idx, val_idx) in enumerate(folds):
    # Create a directory for this fold
    fold_dir = os.path.join(outdir, f"result_{fold_idx + 1}")
    os.makedirs(fold_dir, exist_ok=True)  # Create folder if it doesn't exist
    
    print(f"  Training samples: {len(train_idx)}")
    print(f"  Validation samples: {len(val_idx)}")

    # Split dataset
    train_dataset = Subset(graph_dataset, train_idx)
    test_dataset = Subset(graph_dataset, val_idx)

    print(f"train_data:{len(train_dataset)}, test_data:{len(test_dataset)}")

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)


    # Validate data loaders
    print("Checking train loader...")
    check_batches(train_loader)
    print("Checking validation loader...")
    check_batches(test_loader)

    # Initialize model
    model = SlideGNN_AdvancedMIL(input_dim=1024, hidden_dim=1024, num_classes=4,num_layers=3, dropout=0.3).to(device)
    #model = DDP(model, device_ids=device)

    # Calculate class weights
    class_weights = calculate_class_weights_from_graph(train_dataset, device)

    # Use CrossEntropyLoss with class weights
    criterion = nn.CrossEntropyLoss(weight=class_weights).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
    # Train and evaluate
    best_slide_acc = 0.0  # Best validation accuracy so far
    patience_counter = 0
    patience = 10
    # Train and evaluate
    for epoch in range(1, 101):
        train_loss = train(model, train_loader, optimizer, criterion, device)

        slide_accuracy, slide_score, slide_preds, slide_labels, tile_score, tile_preds, tile_batch = test(model,test_loader, device)

        print(f'Epoch: {epoch:03d}, Train Loss: {train_loss:.4f}, Accuracy:{slide_accuracy:.4f}')
        # -------------- EARLY STOPPING LOGIC --------------
        if slide_accuracy > best_slide_acc:
            best_slide_acc = slide_accuracy
            patience_counter = 0
        else:
            patience_counter += 1

        # Check for early stopping condition
        if patience_counter >= patience:
            print(f"Early stopping triggered at epoch {epoch}.")
            break
        
    # Save model for this fold
    model_path = os.path.join(fold_dir, "GNN_ViT_model.pth")
    torch.save(model.state_dict(), model_path)
    print(f"Model for Fold {fold_idx + 1} saved at {model_path}")

    # Save slide results for this fold in a text file
    save_results_to_text(sample_names, val_idx, slide_labels, slide_preds, slide_score, label_encoder, rank=device, outdir = fold_dir)
            
    # Save tile predictions to an .npz file
    save_tile_results(tile_preds, tile_score, tile_batch, val_idx, sample_names, rank=device, output_dir = fold_dir)
# Out:
#   Training samples: 256
#   Validation samples: 65
# train_data:256, test_data:65
# Checking train loader...
# Step 1:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[57518, 1024], edge_index=[2, 287590], y=[32], batch=[57518], ptr=[33])
#
# Step 2:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[82182, 1024], edge_index=[2, 410910], y=[32], batch=[82182], ptr=[33])
#
# Step 3:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[75031, 1024], edge_index=[2, 375155], y=[32], batch=[75031], ptr=[33])
#
# Step 4:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[80717, 1024], edge_index=[2, 403585], y=[32], batch=[80717], ptr=[33])
#
# Step 5:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[68080, 1024], edge_index=[2, 340400], y=[32], batch=[68080], ptr=[33])
#
# Step 6:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[82279, 1024], edge_index=[2, 411395], y=[32], batch=[82279], ptr=[33])
#
# Step 7:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[83058, 1024], edge_index=[2, 415290], y=[32], batch=[83058], ptr=[33])
#
# Step 8:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[92062, 1024], edge_index=[2, 460310], y=[32], batch=[92062], ptr=[33])
#
# Checking validation loader...
# Step 1:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[89319, 1024], edge_index=[2, 446595], y=[32], batch=[89319], ptr=[33])
#
# Step 2:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[62388, 1024], edge_index=[2, 311940], y=[32], batch=[62388], ptr=[33])
#
# Step 3:
# =======
# Number of graphs in the current batch: 1
# Data in Batch:
# DataBatch(x=[185, 1024], edge_index=[2, 925], y=[1], batch=[185], ptr=[2])
#
# Epoch: 001, Train Loss: 1.4258, Accuracy:0.3231
# Epoch: 002, Train Loss: 1.3768, Accuracy:0.3231
# Epoch: 003, Train Loss: 1.3359, Accuracy:0.3077
# Epoch: 004, Train Loss: 1.1563, Accuracy:0.2154
# Epoch: 005, Train Loss: 0.7777, Accuracy:0.2769
# Epoch: 006, Train Loss: 0.3971, Accuracy:0.2615
# Epoch: 007, Train Loss: 0.2397, Accuracy:0.3538
# Epoch: 008, Train Loss: 0.1542, Accuracy:0.2154
# Epoch: 009, Train Loss: 0.0634, Accuracy:0.2769
# Epoch: 010, Train Loss: 0.0350, Accuracy:0.2615
# Epoch: 011, Train Loss: 0.0197, Accuracy:0.2923
# Epoch: 012, Train Loss: 0.0090, Accuracy:0.2462
# Epoch: 013, Train Loss: 0.0048, Accuracy:0.2769
# Epoch: 014, Train Loss: 0.0035, Accuracy:0.2923
# Epoch: 015, Train Loss: 0.0024, Accuracy:0.2769
# Epoch: 016, Train Loss: 0.0018, Accuracy:0.2769
# Epoch: 017, Train Loss: 0.0012, Accuracy:0.2615
# Early stopping triggered at epoch 17.
# Model for Fold 1 saved at GNN_modle_Malignant_5FCross_multiGPU_old/result_1/GNN_ViT_model.pth
# GPU cuda: Results saved to GNN_modle_Malignant_5FCross_multiGPU_old/result_1/slide_results_rankcuda.txt
# GPU cuda: Saved tile results to GNN_modle_Malignant_5FCross_multiGPU_old/result_1/tile_results_rankcuda.npz
#   Training samples: 257
#   Validation samples: 64
# train_data:257, test_data:64
# Checking train loader...
# Step 1:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[78848, 1024], edge_index=[2, 394240], y=[32], batch=[78848], ptr=[33])
#
# Step 2:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[65238, 1024], edge_index=[2, 326190], y=[32], batch=[65238], ptr=[33])
#
# Step 3:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[100915, 1024], edge_index=[2, 504575], y=[32], batch=[100915], ptr=[33])
#
# Step 4:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[59117, 1024], edge_index=[2, 295585], y=[32], batch=[59117], ptr=[33])
#
# Step 5:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[81302, 1024], edge_index=[2, 406510], y=[32], batch=[81302], ptr=[33])
#
# Step 6:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[66470, 1024], edge_index=[2, 332350], y=[32], batch=[66470], ptr=[33])
#
# Step 7:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[89034, 1024], edge_index=[2, 445170], y=[32], batch=[89034], ptr=[33])
#
# Step 8:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[82163, 1024], edge_index=[2, 410815], y=[32], batch=[82163], ptr=[33])
#
# Step 9:
# =======
# Number of graphs in the current batch: 1
# Data in Batch:
# DataBatch(x=[234, 1024], edge_index=[2, 1170], y=[1], batch=[234], ptr=[2])
#
# Checking validation loader...
# Step 1:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[75133, 1024], edge_index=[2, 375665], y=[32], batch=[75133], ptr=[33])
#
# Step 2:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[74365, 1024], edge_index=[2, 371825], y=[32], batch=[74365], ptr=[33])
#
# Epoch: 001, Train Loss: 1.4245, Accuracy:0.2031
# Epoch: 002, Train Loss: 1.3832, Accuracy:0.3438
# Epoch: 003, Train Loss: 1.2832, Accuracy:0.2969
# Epoch: 004, Train Loss: 1.1829, Accuracy:0.3281
# Epoch: 005, Train Loss: 0.7560, Accuracy:0.1719
# Epoch: 006, Train Loss: 0.6922, Accuracy:0.3750
# Epoch: 007, Train Loss: 0.1513, Accuracy:0.2656
# Epoch: 008, Train Loss: 0.0989, Accuracy:0.2969
# Epoch: 009, Train Loss: 0.0518, Accuracy:0.3125
# Epoch: 010, Train Loss: 0.0236, Accuracy:0.3750
# Epoch: 011, Train Loss: 0.0342, Accuracy:0.3281
# Epoch: 012, Train Loss: 0.0090, Accuracy:0.3281
# Epoch: 013, Train Loss: 0.0041, Accuracy:0.3750
# Epoch: 014, Train Loss: 0.0796, Accuracy:0.3750
# Epoch: 015, Train Loss: 0.0029, Accuracy:0.3594
# Epoch: 016, Train Loss: 0.0038, Accuracy:0.3438
# Early stopping triggered at epoch 16.
# Model for Fold 2 saved at GNN_modle_Malignant_5FCross_multiGPU_old/result_2/GNN_ViT_model.pth
# GPU cuda: Results saved to GNN_modle_Malignant_5FCross_multiGPU_old/result_2/slide_results_rankcuda.txt
# GPU cuda: Saved tile results to GNN_modle_Malignant_5FCross_multiGPU_old/result_2/tile_results_rankcuda.npz
#   Training samples: 257
#   Validation samples: 64
# train_data:257, test_data:64
# Checking train loader...
# Step 1:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[63842, 1024], edge_index=[2, 319210], y=[32], batch=[63842], ptr=[33])
#
# Step 2:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[87958, 1024], edge_index=[2, 439790], y=[32], batch=[87958], ptr=[33])
#
# Step 3:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[79907, 1024], edge_index=[2, 399535], y=[32], batch=[79907], ptr=[33])
#
# Step 4:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[82081, 1024], edge_index=[2, 410405], y=[32], batch=[82081], ptr=[33])
#
# Step 5:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[88911, 1024], edge_index=[2, 444555], y=[32], batch=[88911], ptr=[33])
#
# Step 6:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[65332, 1024], edge_index=[2, 326660], y=[32], batch=[65332], ptr=[33])
#
# Step 7:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[83557, 1024], edge_index=[2, 417785], y=[32], batch=[83557], ptr=[33])
#
# Step 8:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[75114, 1024], edge_index=[2, 375570], y=[32], batch=[75114], ptr=[33])
#
# Step 9:
# =======
# Number of graphs in the current batch: 1
# Data in Batch:
# DataBatch(x=[244, 1024], edge_index=[2, 1220], y=[1], batch=[244], ptr=[2])
#
# Checking validation loader...
# Step 1:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[78695, 1024], edge_index=[2, 393475], y=[32], batch=[78695], ptr=[33])
#
# Step 2:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[67178, 1024], edge_index=[2, 335890], y=[32], batch=[67178], ptr=[33])
#
# Epoch: 001, Train Loss: 1.4051, Accuracy:0.1250
# Epoch: 002, Train Loss: 1.3677, Accuracy:0.3281
# Epoch: 003, Train Loss: 1.3493, Accuracy:0.1406
# Epoch: 004, Train Loss: 1.2705, Accuracy:0.3281
# Epoch: 005, Train Loss: 0.8199, Accuracy:0.2344
# Epoch: 006, Train Loss: 0.5756, Accuracy:0.1719
# Epoch: 007, Train Loss: 0.4525, Accuracy:0.2500
# Epoch: 008, Train Loss: 0.3072, Accuracy:0.2656
# Epoch: 009, Train Loss: 0.1154, Accuracy:0.3281
# Epoch: 010, Train Loss: 0.0640, Accuracy:0.2031
# Epoch: 011, Train Loss: 0.0655, Accuracy:0.2031
# Epoch: 012, Train Loss: 0.0659, Accuracy:0.1719
# Early stopping triggered at epoch 12.
# Model for Fold 3 saved at GNN_modle_Malignant_5FCross_multiGPU_old/result_3/GNN_ViT_model.pth
# GPU cuda: Results saved to GNN_modle_Malignant_5FCross_multiGPU_old/result_3/slide_results_rankcuda.txt
# GPU cuda: Saved tile results to GNN_modle_Malignant_5FCross_multiGPU_old/result_3/tile_results_rankcuda.npz
#   Training samples: 257
#   Validation samples: 64
# train_data:257, test_data:64
# Checking train loader...
# Step 1:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[68383, 1024], edge_index=[2, 341915], y=[32], batch=[68383], ptr=[33])
#
# Step 2:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[88371, 1024], edge_index=[2, 441855], y=[32], batch=[88371], ptr=[33])
#
# Step 3:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[81136, 1024], edge_index=[2, 405680], y=[32], batch=[81136], ptr=[33])
#
# Step 4:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[73761, 1024], edge_index=[2, 368805], y=[32], batch=[73761], ptr=[33])
#
# Step 5:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[77165, 1024], edge_index=[2, 385825], y=[32], batch=[77165], ptr=[33])
#
# Step 6:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[83474, 1024], edge_index=[2, 417370], y=[32], batch=[83474], ptr=[33])
#
# Step 7:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[62621, 1024], edge_index=[2, 313105], y=[32], batch=[62621], ptr=[33])
#
# Step 8:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[83813, 1024], edge_index=[2, 419065], y=[32], batch=[83813], ptr=[33])
#
# Step 9:
# =======
# Number of graphs in the current batch: 1
# Data in Batch:
# DataBatch(x=[3550, 1024], edge_index=[2, 17750], y=[1], batch=[3550], ptr=[2])
#
# Checking validation loader...
# Step 1:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[81374, 1024], edge_index=[2, 406870], y=[32], batch=[81374], ptr=[33])
#
# Step 2:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[69171, 1024], edge_index=[2, 345855], y=[32], batch=[69171], ptr=[33])
#
# Epoch: 001, Train Loss: 1.4042, Accuracy:0.1406
# Epoch: 002, Train Loss: 1.3755, Accuracy:0.3125
# Epoch: 003, Train Loss: 1.3426, Accuracy:0.1250
# Epoch: 004, Train Loss: 1.1737, Accuracy:0.3125
# Epoch: 005, Train Loss: 0.8964, Accuracy:0.1875
# Epoch: 006, Train Loss: 0.4634, Accuracy:0.2344
# Epoch: 007, Train Loss: 0.2470, Accuracy:0.2031
# Epoch: 008, Train Loss: 0.3276, Accuracy:0.1875
# Epoch: 009, Train Loss: 0.1188, Accuracy:0.2344
# Epoch: 010, Train Loss: 0.0308, Accuracy:0.2500
# Epoch: 011, Train Loss: 0.0714, Accuracy:0.1875
# Epoch: 012, Train Loss: 0.0571, Accuracy:0.2812
# Early stopping triggered at epoch 12.
# Model for Fold 4 saved at GNN_modle_Malignant_5FCross_multiGPU_old/result_4/GNN_ViT_model.pth
# GPU cuda: Results saved to GNN_modle_Malignant_5FCross_multiGPU_old/result_4/slide_results_rankcuda.txt
# GPU cuda: Saved tile results to GNN_modle_Malignant_5FCross_multiGPU_old/result_4/tile_results_rankcuda.npz
#   Training samples: 257
#   Validation samples: 64
# train_data:257, test_data:64
# Checking train loader...
# Step 1:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[79313, 1024], edge_index=[2, 396565], y=[32], batch=[79313], ptr=[33])
#
# Step 2:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[76284, 1024], edge_index=[2, 381420], y=[32], batch=[76284], ptr=[33])
#
# Step 3:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[84914, 1024], edge_index=[2, 424570], y=[32], batch=[84914], ptr=[33])
#
# Step 4:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[75127, 1024], edge_index=[2, 375635], y=[32], batch=[75127], ptr=[33])
#
# Step 5:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[58197, 1024], edge_index=[2, 290985], y=[32], batch=[58197], ptr=[33])
#
# Step 6:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[75859, 1024], edge_index=[2, 379295], y=[32], batch=[75859], ptr=[33])
#
# Step 7:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[65817, 1024], edge_index=[2, 329085], y=[32], batch=[65817], ptr=[33])
#
# Step 8:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[78409, 1024], edge_index=[2, 392045], y=[32], batch=[78409], ptr=[33])
#
# Step 9:
# =======
# Number of graphs in the current batch: 1
# Data in Batch:
# DataBatch(x=[3888, 1024], edge_index=[2, 19440], y=[1], batch=[3888], ptr=[2])
#
# Checking validation loader...
# Step 1:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[97927, 1024], edge_index=[2, 489635], y=[32], batch=[97927], ptr=[33])
#
# Step 2:
# =======
# Number of graphs in the current batch: 32
# Data in Batch:
# DataBatch(x=[77084, 1024], edge_index=[2, 385420], y=[32], batch=[77084], ptr=[33])
#
# Epoch: 001, Train Loss: 1.4032, Accuracy:0.3438
# Epoch: 002, Train Loss: 1.3493, Accuracy:0.4531
# Epoch: 003, Train Loss: 1.4404, Accuracy:0.4219
# Epoch: 004, Train Loss: 1.2575, Accuracy:0.1406
# Epoch: 005, Train Loss: 0.9232, Accuracy:0.4219
# Epoch: 006, Train Loss: 0.5839, Accuracy:0.4375
# Epoch: 007, Train Loss: 0.4062, Accuracy:0.4375
# Epoch: 008, Train Loss: 0.3937, Accuracy:0.3906
# Epoch: 009, Train Loss: 0.0835, Accuracy:0.4219
# Epoch: 010, Train Loss: 0.0690, Accuracy:0.4062
# Epoch: 011, Train Loss: 0.0481, Accuracy:0.3906
# Epoch: 012, Train Loss: 0.0285, Accuracy:0.2812
# Early stopping triggered at epoch 12.
# Model for Fold 5 saved at GNN_modle_Malignant_5FCross_multiGPU_old/result_5/GNN_ViT_model.pth
# GPU cuda: Results saved to GNN_modle_Malignant_5FCross_multiGPU_old/result_5/slide_results_rankcuda.txt
# GPU cuda: Saved tile results to GNN_modle_Malignant_5FCross_multiGPU_old/result_5/tile_results_rankcuda.npz

# %%
# Collect and combine tile level results
combine_tile_level_results(outdir)

# Collect slide results data
true_labels, predicted_labels, predicted_scores = aggregate_slide_level_results(outdir)

# Annalyze slide results data
analyze_results(true_labels, predicted_labels, predicted_scores, label_encoder,outdir=outdir)
# Out:
# Loading GNN_modle_Malignant_5FCross_multiGPU_old/result_2/tile_results_rankcuda.npz...
# Loading GNN_modle_Malignant_5FCross_multiGPU_old/result_4/tile_results_rankcuda.npz...
# Loading GNN_modle_Malignant_5FCross_multiGPU_old/result_1/tile_results_rankcuda.npz...
# Loading GNN_modle_Malignant_5FCross_multiGPU_old/result_3/tile_results_rankcuda.npz...
# Loading GNN_modle_Malignant_5FCross_multiGPU_old/result_5/tile_results_rankcuda.npz...
# Combined tile results saved to GNN_modle_Malignant_5FCross_multiGPU_old/combined_tile_results.npz
# Processing fold directory: GNN_modle_Malignant_5FCross_multiGPU_old/result_1
#   Loading file: GNN_modle_Malignant_5FCross_multiGPU_old/result_1/slide_results_rankcuda.txt
# Processing fold directory: GNN_modle_Malignant_5FCross_multiGPU_old/result_2
#   Loading file: GNN_modle_Malignant_5FCross_multiGPU_old/result_2/slide_results_rankcuda.txt
# Processing fold directory: GNN_modle_Malignant_5FCross_multiGPU_old/result_3
#   Loading file: GNN_modle_Malignant_5FCross_multiGPU_old/result_3/slide_results_rankcuda.txt
# Processing fold directory: GNN_modle_Malignant_5FCross_multiGPU_old/result_4
#   Loading file: GNN_modle_Malignant_5FCross_multiGPU_old/result_4/slide_results_rankcuda.txt
# Processing fold directory: GNN_modle_Malignant_5FCross_multiGPU_old/result_5
#   Loading file: GNN_modle_Malignant_5FCross_multiGPU_old/result_5/slide_results_rankcuda.txt
# Total aggregated data shape: (321, 7)
# Aggregated slide-level results saved to GNN_modle_Malignant_5FCross_multiGPU_old/aggregated_slide_results.csv
# Confusion matrix heatmap saved to GNN_modle_Malignant_5FCross_multiGPU_old/confusion_matrix_heatmap.png
# ROC AUC plot saved to GNN_modle_Malignant_5FCross_multiGPU_old/roc_auc_curve.png
# Data Analysis Done!

# %%
from tile_categarical_heamp import*
outdir ="GNN_modle_Malignant_5FCross_multiGPU"
slide_name = "BM51_ST-22-34_A-1_-_2022-01-25_10.54.58.ndpi"
slide_file_name = os.path.join("/data/NCI_LP/pediatric_Data/Medulloblastoma/NCI_MB_GP34/slides",slide_name)
all_tile_result = np.load(os.path.join(outdir,"combined_tile_results.npz"),allow_pickle=True)
tile_result = all_tile_result[slide_name]
tile_dict = tile_result.item()  # Extract the dictionary from the array
tile_labels = tile_dict['tile_preds']
print(tile_labels)
tile_coord_path = "/data/NCI_LP/pediatric_Data/Medulloblastoma/NCI_MB_GP34/outputs/NCI_MB_GP34_example/NCI_MB_GP34_coordinates/"
slide_coord_name = slide_name+"_tile_coordinates.csv"
tile_coords = pd.read_csv(os.path.join(tile_coord_path,slide_coord_name))
tile_coords = tile_coords.to_numpy()
# Out:
# [0 0 0 ... 0 0 0]

# %%
import os
import numpy as np
import openslide
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.patches import Patch

def create_categorical_heatmap(
    tile_coords,
    tile_labels,
    slide_file_name,
    class_idx=None,
    tile_size=512,
    downsample=16,
    categories=None,
    category_colors=None,
    overwrite_policy='background_only'
):
    """
    Create a categorical heatmap for a single slide from tile labels.

    Args:
        tile_coords (np.ndarray): shape [N, 2], each row=(row, col) in original resolution.
        tile_labels (np.ndarray): shape [N], integer labels for each tile.
        slide_file_name (str): Path to the WSI.
        class_idx (int, optional): If specified, only visualize this label.
        tile_size (int): Original tile width/height in pixels.
        downsample (int): Factor to downsample the slide for heatmap.
        categories (dict, optional): Mapping from label -> category name.
        category_colors (dict, optional): Mapping from label -> color (string).
        overwrite_policy (str): 'background_only' means only fill empty (0),
            'overwrite' means always overwrite.

    Returns:
        heatmap (np.ndarray): shape (H_ds, W_ds) with integer labels.
    """

    # 1. Check input lengths
    if len(tile_coords) != len(tile_labels):
        raise ValueError("tile_coords and tile_labels must be the same length.")

    # Provide default categories if needed
    if categories is None:
        categories = {
            0: 'Background',
            1: 'Neural.Crest',
            2: 'Neuronal',
            3: 'Photoreceptor',
            4: 'Proliferative'
        }
    # Provide default colors if needed
    if category_colors is None:
        category_colors = {
            0: 'white',     # background
            1: 'green',     
            2: 'yellow',
            3: 'blue',
            4: 'pink'
        }

    # Print some debug info
    print(f"Number of tiles: {len(tile_coords)}")
    unique_tile_labels = np.unique(tile_labels)
    print("Unique labels in tile_labels:", unique_tile_labels)

    # 2. Open slide with OpenSlide
    try:
        slide = openslide.OpenSlide(slide_file_name)
    except Exception as e:
        raise IOError(f"Could not open slide file {slide_file_name}: {e}")

    properties = slide.properties
    mag_key = openslide.PROPERTY_NAME_OBJECTIVE_POWER
    if mag_key in properties:
        mag_max = float(properties[mag_key])
        print(f"Slide magnification: {mag_max}x")
    else:
        mag_assumed = 20.0
        mag_max = mag_assumed
        print(f"[WARNING] Magnification not found. Assuming {mag_assumed}x")

    # 3. Determine slide dimensions at the highest level (level=0)
    slide_width_0, slide_height_0 = slide.level_dimensions[0]

    # Downsample for the heatmap space
    slide_width = slide_width_0 // downsample
    slide_height = slide_height_0 // downsample
    print(f"Slide dimensions at downsample=1/{downsample}: {slide_width}x{slide_height}")

    # 4. Create heatmap array
    heatmap = np.zeros((slide_height, slide_width), dtype=np.int32)

    # Downsample tile size
    tile_size_ds = tile_size // downsample

    # 5. Populate the heatmap
    #   If your coords are row=(y), col=(x), we do row_ds = row//downsample, col_ds = col//downsample
    #   If class_idx is given, we skip tiles that are not that label.
    for idx, (row, col) in enumerate(tile_coords):
        label = tile_labels[idx]

        if class_idx is not None and label != class_idx:
            continue

        row_ds = row // downsample
        col_ds = col // downsample

        row_start = max(0, row_ds)
        row_end   = min(slide_height, row_ds + tile_size_ds)
        col_start = max(0, col_ds)
        col_end   = min(slide_width,  col_ds + tile_size_ds)

        # Print debug info for the first few tiles or if label != 0
        if idx < 10 or label != 0:
            print(f"[Tile {idx}] row={row}, col={col}, label={label}")
            print(f"  region=({row_start}:{row_end}, {col_start}:{col_end})")

        # Depending on the overwrite policy, we either fill only background or overwrite always
        if overwrite_policy == 'background_only':
            # fill label only where heatmap == 0
            existing = heatmap[row_start:row_end, col_start:col_end]
            mask = (existing == 0)
            existing[mask] = label
        else:
            # Always overwrite any existing label
            heatmap[row_start:row_end, col_start:col_end] = label

    # 6. Debug: check final unique labels in the heatmap
    unique_vals_heatmap = np.unique(heatmap)
    print("Unique values in heatmap:", unique_vals_heatmap)

    # 7. Build the color map
    max_label = max(categories.keys())
    color_list = []
    for lbl in range(max_label+1):
        color = category_colors.get(lbl, 'gray')
        color_list.append(color)
    cmap = mcolors.ListedColormap(color_list)
    bounds = list(range(max_label+2))
    norm = mcolors.BoundaryNorm(bounds, cmap.N)

    # 8. Plot
    plt.figure(figsize=(10, 10))
    plt.imshow(heatmap, cmap=cmap, norm=norm, alpha=1.0)  # alpha=1.0 => fully opaque
    plt.axis('off')
    plt.title('Categorical Heatmap Overlay', fontsize=16)

    # Create legend
    legend_elements = []
    for lbl, cat_name in categories.items():
        if category_colors.get(lbl, 'white') != 'none':
            legend_elements.append(
                Patch(facecolor=category_colors[lbl], edgecolor='black', label=cat_name)
            )
    plt.legend(handles=legend_elements, bbox_to_anchor=(1.05,1), loc='upper left')

    # 9. Save figure
    heatmap_save_path = os.path.splitext(slide_file_name)[0] + '_heatmap.png'
    plt.savefig(heatmap_save_path, bbox_inches='tight', dpi=300)
    plt.close()

    print(f"Categorical heatmap saved to {heatmap_save_path}")

    return heatmap

# %%
heatmap = create_categorical_heatmap(tile_coords, tile_labels, slide_file_name,
                           class_idx=None, tile_size=512, downsample=16,
                           categories=categories, category_colors=category_colors)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 heatmap = create_categorical_heatmap(tile_coords, tile_labels, slide_file_name,
#       2                            class_idx=None, tile_size=512, downsample=16,
#       3                            categories=categories, category_colors=category_colors)
#
# NameError: name 'create_categorical_heatmap' is not defined

# %%
import os
import numpy as np
import openslide
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.patches import Patch

def overlay_tiles_on_wsi(
    slide_path: str,
    tile_coords: np.ndarray,   # shape (N,2) in level 0 coords
    tile_labels: np.ndarray,   # shape (N,) numeric
    tile_size: int = 512,
    level_for_display: int = 2,
    label_names=None,          # dict label->string
    label_colors=None,         # dict label->(r,g,b,a)
    output_dir: str = "./output",
    output_prefix: str = "overlay"
):
    """
    Overlays semi-transparent colored rectangles for tile labels on a downsampled WSI image.
    """

    # Open the slide
    slide = openslide.OpenSlide(slide_path)
    if level_for_display >= slide.level_count:
        raise ValueError(f"Invalid level {level_for_display}, max is {slide.level_count-1}")

    # Dimensions at this level
    display_width, display_height = slide.level_dimensions[level_for_display]
    downsample_factor = slide.level_downsamples[level_for_display]

    print(f"Using level {level_for_display} => dimension: {display_width}x{display_height}, "
          f"downsample={downsample_factor}")

    # Read the region at this level
    display_region = slide.read_region((0,0), level_for_display, (display_width, display_height))
    display_image = display_region.convert('RGB')
    display_image_np = np.array(display_image)

    # Default label->name mapping if not provided
    if label_names is None:
        label_names = {
            0: "Neural-crest",
            1: "Neuronal",
            2: "Photoreceptor",
            3: "Proliferative",
        }

    # Default label->RGBA color mapping if not provided
    if label_colors is None:
        label_colors = {
            0: (1.0, 0.0, 0.0, 0.3),
            1: (0.0, 1.0, 0.0, 0.3),
            2: (0.0, 0.0, 1.0, 0.3),
            3: (1.0, 1.0, 0.0, 0.3),
        }

    # Create matplotlib figure
    fig, ax = plt.subplots(figsize=(12, 12))
    ax.imshow(display_image_np)
    ax.axis('off')

    # Draw rectangles for each tile
    for i, (row_level0, col_level0) in enumerate(tile_coords):
        lbl = tile_labels[i]
        color = label_colors.get(lbl, (1.0, 1.0, 1.0, 0.3))  # fallback color if not found

        # Downsample coords
        row_ds = row_level0 / downsample_factor
        col_ds = col_level0 / downsample_factor
        tile_size_ds = tile_size / downsample_factor

        rect = patches.Rectangle(
            (col_ds, row_ds),
            tile_size_ds,
            tile_size_ds,
            linewidth=1,
            edgecolor=color[:3],  # ignoring alpha for edge
            facecolor=color
        )
        ax.add_patch(rect)

        # Optional debug for first few
        if i < 5:
            name = label_names.get(lbl, f"Label {lbl}")
            print(f"Tile {i} => label={lbl} ({name}), region=({col_ds},{row_ds}), size={tile_size_ds}")

    # Build a legend from label_names
    legend_patches = []
    for lbl, name in label_names.items():
        c = label_colors.get(lbl, (1.0, 1.0, 1.0, 0.3))
        legend_patches.append(Patch(facecolor=c, label=name))
    ax.legend(handles=legend_patches, bbox_to_anchor=(1.05,1), loc='upper left')

    # Save
    os.makedirs(output_dir, exist_ok=True)
    output_path = os.path.join(output_dir, f"{output_prefix}_level{level_for_display}.png")
    plt.savefig(output_path, bbox_inches='tight', dpi=300)
    plt.close()
    print(f"Saved overlay to {output_path}")

# %%
# Provide custom names if you prefer
label_names = {
    0: "Neural-crest",
    1: "Neuronal",
    2: "Photoreceptor",
    3: "proliferative"
        # If you have a label 1 or 4, define them too
}
# Provide custom colors if desired
label_colors = {
    0: 'red',
    1: 'green',
    2: 'blue',
    3: 'magenta'
}

overlay_tiles_on_wsi(
    slide_path=slide_file_name,
    tile_coords=tile_coords,
    tile_labels=tile_labels,
    tile_size=512,
    level_for_display=2,    # a downsampled level
    label_names=None,
    label_colors=None,
    output_dir=outdir,
    output_prefix="BM51_Image1"
)
# Out:
# Using level 2 => dimension: 22080x23232, downsample=4.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 17
#       9 # Provide custom colors if desired
#      10 label_colors = {
#      11     0: 'red',
#      12     1: 'green',
#      13     2: 'blue',
#      14     3: 'magenta'
#      15 }
# ---> 17 overlay_tiles_on_wsi(
#      18     slide_path=slide_file_name,
#      19     tile_coords=tile_coords,
#      20     tile_labels=tile_labels,
#      21     tile_size=512,
#      22     level_for_display=2,    # a downsampled level
#      23     label_names=None,
#      24     label_colors=None,
#      25     output_dir=outdir,
#      26     output_prefix="BM51_Image1"
#      27 )
#
# Cell In[9], line 65, in overlay_tiles_on_wsi(slide_path, tile_coords, tile_labels, tile_size, level_for_display, label_names, label_colors, output_dir, output_prefix)
#      62 ax.axis('off')
#      64 # Draw rectangles for each tile
# ---> 65 for i, (row_level0, col_level0) in enumerate(tile_coords):
#      66     lbl = tile_labels[i]
#      67     color = label_colors.get(lbl, (1.0, 1.0, 1.0, 0.3))  # fallback color if not found
#
# ValueError: too many values to unpack (expected 2)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.patches import Patch
import os

def create_categorical_heatmap(tile_coords, tile_labels, tile_size=256, downsample=2,
                               categories=None, category_colors=None,
                               output_path="heatmap.png"):
    """
    Create and save a categorical heatmap from tile coordinates and labels,
    without overlaying on an H&E slide.

    Args:
        tile_coords (np.ndarray): shape [N, 2], each row = (row, col) or (y, x)
                                  for top-left corner of tile in original resolution.
        tile_labels (np.ndarray): shape [N], integer labels for each tile.
        tile_size (int): width/height of each tile in pixels.
        downsample (int): factor to downsample the heatmap. E.g. 16 => 1/16 scale.
        categories (dict): label -> category name for the legend.
        category_colors (dict): label -> color (any matplotlib color format).
        output_path (str): file path to save the heatmap image.

    Returns:
        heatmap (np.ndarray): A 2D integer array with shape [H, W] containing labels.
    """

    # Sanity check
    if len(tile_coords) != len(tile_labels):
        raise ValueError("tile_coords and tile_labels must have the same length.")

    # Provide default categories if not given
    if categories is None:
        categories = {
            0: "Background",
            1: "Neural-crest",
            2: "Neuronal",
            3: "Photoreceptor",
            4: "Proliferative"
        }

    # Provide default colors if not given
    if category_colors is None:
        category_colors = {
            0: "white",
            1: "red",
            2: "green",
            3: "blue",
            4: "magenta"
        }

    # 1) Determine the shape of the heatmap
    #    We find the max row, col among tile_coords plus tile_size,
    #    then optionally downsample.
    
    max_row = 0
    max_col = 0
    for (row, col) in tile_coords:
        # The bottom-right corner of this tile is row+tile_size, col+tile_size
        if row + tile_size > max_row:
            max_row = row + tile_size
        if col + tile_size > max_col:
            max_col = col + tile_size

    # Downsample the final array
    heatmap_height = (max_row // downsample)
    heatmap_width  = (max_col // downsample)

    print(f"Heatmap dimensions: {heatmap_height} x {heatmap_width}")

    # 2) Create the empty heatmap (background label = -1)
    heatmap = np.zeros((heatmap_height, heatmap_width), dtype=np.int32)

    # 3) Populate the heatmap
    tile_size_ds = tile_size // downsample
    for i, (row, col) in enumerate(tile_coords):
        label = tile_labels[i]

        row_ds = row // downsample
        col_ds = col // downsample

        row_start = row_ds
        row_end   = row_ds * tile_size_ds
        col_start = col_ds
        col_end   = col_ds * tile_size_ds

        # Bound check
        if row_end > heatmap_height:
            row_end = heatmap_height
        if col_end > heatmap_width:
            col_end = heatmap_width

        heatmap[row_start:row_end, col_start:col_end] = label

    # 4) Build a ListedColormap for the labels
    max_label = max(categories.keys())
    # Create a color list for each label 0..max_label
    color_list = []
    for l in range(max_label+1):
        color_list.append(category_colors.get(l, "yellow"))  # fallback

    cmap = mcolors.ListedColormap(color_list)
    bounds = list(range(max_label+2))  # e.g. 0..max_label+1
    norm = mcolors.BoundaryNorm(bounds, cmap.N)

    # 5) Plot the heatmap
    fig, ax = plt.subplots(figsize=(10, 10))
    im = ax.imshow(heatmap, cmap=cmap, norm=norm, origin='upper')  # origin='upper' for row->y
    ax.axis("off")
    ax.set_title("Categorical Tile Heatmap", fontsize=16)

    # 6) Create a legend
    from matplotlib.patches import Patch
    legend_elements = []
    for lbl, cat_name in categories.items():
        color_val = category_colors.get(lbl, "yellow")
        legend_elements.append(Patch(facecolor=color_val, label=cat_name))
    ax.legend(handles=legend_elements, bbox_to_anchor=(1.05,1), loc='upper left')

    # 7) Save the figure
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    plt.savefig(output_path, bbox_inches='tight', dpi=300)
    plt.close()

    print(f"Saved heatmap to {output_path}")
    return heatmap

# %%
# Create the heatmap
heatmap_array = create_categorical_heatmap(
    tile_coords=tile_coords,
    tile_labels=tile_labels,
    tile_size=256,
    categories=categories,
    category_colors=category_colors,
    output_path=os.path.join(outdir,"BM51_categorical_heatmap.png")
)
# Out:
# Heatmap dimensions: 171 x 169
# Saved heatmap to GNN_modle_Malignant_5FCross_multiGPU/BM51_categorical_heatmap.png

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.patches import Patch
import os

def create_categorical_heatmap(tile_coords, tile_labels, tile_size=512, downsample=2,
                               categories=None, category_colors=None,
                               output_path="heatmap.png"):
    """
    Create and save a categorical heatmap from tile coordinates and labels,
    without overlaying on an H&E slide.

    Args:
        tile_coords (np.ndarray): shape [N, 2], each row = (row, col) or (y, x)
                                  for top-left corner of tile in original resolution.
        tile_labels (np.ndarray): shape [N], integer labels for each tile.
        tile_size (int): width/height of each tile in pixels.
        downsample (int): factor to downsample the heatmap. E.g. 16 => 1/16 scale.
        categories (dict): label -> category name for the legend.
        category_colors (dict): label -> color (any matplotlib color format).
        output_path (str): file path to save the heatmap image.

    Returns:
        heatmap (np.ndarray): A 2D integer array with shape [H, W] containing labels.
    """

    # Sanity check
    if len(tile_coords) != len(tile_labels):
        raise ValueError("tile_coords and tile_labels must have the same length.")

    # Provide default categories if not given
    if categories is None:
        categories = {
            0: "Background",
            1: "Neural-crest",
            2: "Neuronal",
            3: "Photoreceptor",
            4: "Proliferative"
        }

    # Provide default colors if not given
    if category_colors is None:
        category_colors = {
            0: "white",
            1: "red",
            2: "green",
            3: "blue",
            4: "magenta"
        }
    # 1) Open the WSI slide
    try:
        slide = openslide.OpenSlide(slide_file_name)
    except Exception as e:
        raise IOError(f"Could not open slide file {slide_file_name}: {e}")
    ## magnification max
    if openslide.PROPERTY_NAME_OBJECTIVE_POWER in slide.properties:
        mag_max = slide.properties[openslide.PROPERTY_NAME_OBJECTIVE_POWER]
        print("mag_max:", mag_max)
        mag_original = mag_max
    else:
        print("[WARNING] mag not found, assuming: {mag_assumed}")
        mag_max = 40
        mag_original = 0

    ## downsample_level
    downsampling = int(int(mag_max)/20)
    print(f"downsampling: {downsampling}")
    
    # 2) Get dimensions at level 0 and chosen level
    px0, py0 = slide.level_dimensions[0]  # Level 0 (original resolution)
    tile_size0 = int(512*downsampling)
    n_rows,n_cols = int(py0/tile_size0), int(px0/tile_size0)
    print(f"tiles from original image n_rows: {n_rows}, n_cols: {n_cols}, total tiles: {n_rows*n_cols}")
    
    # 1) Determine the shape of the heatmap
    #    We find the max row, col among tile_coords plus tile_size,
    #    then optionally downsample.
    
    print(f"tile size:{len(tile_coords)}")
    # Ensure correct heatmap size
    #max_row = len(np.unique(tile_coords[:, 0]))
    #max_col = len(np.unique(tile_coords[:, 1]))

   

    #print(f"tiles from tile_coord file max_rows: {max_row}, max_cols: {max_col}, total tiles: {max_row*max_col}")
    
    # Downsample the final array
    mask_tile_size = int(np.ceil(tile_size/16))
    heatmap_height = n_rows*tile_size0
    heatmap_width = n_cols*tile_size0

    print(f"Heatmap dimensions: {heatmap_height} x {heatmap_width}")

    # 2) Create the empty heatmap (background label = -1)
    heatmap = np.zeros((heatmap_height, heatmap_width), dtype=np.int32)

    # 3) Populate the heatmap
    tile_size_ds = tile_size // downsample
    for i, (row, col) in enumerate(tile_coords):
        label = tile_labels[i]

        row_start= row // downsample
        col_start = col // downsample

        # Correct tile placement within heatmap bounds
        row_end = min(row_start + (tile_size // downsample), heatmap_height)
        col_end = min(col_start + (tile_size // downsample), heatmap_width)
        # Bound check
        if row_end > heatmap_height:
            row_end = heatmap_height
        if col_end > heatmap_width:
            col_end = heatmap_width

        heatmap[row_start:row_end, col_start:col_end] = label

    # 4) Build a ListedColormap for the labels
    max_label = max(categories.keys())
    # Create a color list for each label 0..max_label
    color_list = []
    for l in range(max_label+1):
        color_list.append(category_colors.get(l, "yellow"))  # fallback

    cmap = mcolors.ListedColormap(color_list)
    bounds = list(range(max_label+2))  # e.g. 0..max_label+1
    norm = mcolors.BoundaryNorm(bounds, cmap.N)

    # 5) Plot the heatmap
    fig, ax = plt.subplots(figsize=(10, 10))
    im = ax.imshow(heatmap, cmap=cmap, norm=norm, origin='upper')  # origin='upper' for row->y
    ax.axis("off")
    ax.set_title("Categorical Tile Heatmap", fontsize=16)

    # 6) Create a legend
    from matplotlib.patches import Patch
    legend_elements = []
    for lbl, cat_name in categories.items():
        color_val = category_colors.get(lbl, "yellow")
        legend_elements.append(Patch(facecolor=color_val, label=cat_name))
    ax.legend(handles=legend_elements, bbox_to_anchor=(1.05,1), loc='upper left')

    # 7) Save the figure
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    plt.savefig(output_path, bbox_inches='tight', dpi=300)
    plt.close()

    print(f"Saved heatmap to {output_path}")
    return heatmap

# %%
# Create the heatmap
heatmap_array = create_categorical_heatmap(
    tile_coords=tile_coords,
    tile_labels=tile_labels,
    tile_size=256,
    categories=categories,
    category_colors=category_colors,
    output_path=os.path.join(outdir,"BM51_categorical_heatmap.png")
)
# Out:
# mag_max: 40
# downsampling: 2
# tiles from original image n_rows: 90, n_cols: 86, total tiles: 7740
# tile size:3006
# Heatmap dimensions: 92160 x 88064
# Saved heatmap to GNN_modle_Malignant_5FCross_multiGPU/BM51_categorical_heatmap.png

# %%
categories = {
    0: "Background",
    1: "Neural-crest",
    2: "Neuronal",
    3: "Photoreceptor",
    4: "Proliferative"
}
category_colors = {
    0: "white",
    1: "red",
    2: "green",
    3: "blue",
    4: "magenta"
}

# Create the heatmap
heatmap_array = create_categorical_heatmap(
    slide_file_name,
    tile_coords=tile_coords,
    tile_labels=tile_labels,
    level=0,
    tile_size=512,
    categories=categories,
    category_colors=category_colors,
    output_path=os.path.join(outdir,"BM51_categorical_heatmap.png")
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 17
#       8 category_colors = {
#       9     0: "white",
#      10     1: "red",
#    (...)
#      13     4: "magenta"
#      14 }
#      16 # Create the heatmap
# ---> 17 heatmap_array = create_categorical_heatmap(
#      18     slide_file_name,
#      19     tile_coords=tile_coords,
#      20     tile_labels=tile_labels,
#      21     level=0,
#      22     tile_size=512,
#      23     categories=categories,
#      24     category_colors=category_colors,
#      25     output_path=os.path.join(outdir,"BM51_categorical_heatmap.png")
#      26 )
#
# TypeError: create_categorical_heatmap() got multiple values for argument 'tile_coords'

# %%
import openslide
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.patches import Patch
import os

def create_categorical_heatmap(
    slide_file_name,
    tile_coords,
    tile_labels,
    level=2,
    downsample_factor=4,  # Adjust based on visualization needs
    categories=None,
    category_colors=None,
    output_path="heatmap.png"
):
    """
    Create a categorical heatmap without overlapping tiles.

    Args:
        slide_file_name (str): Path to the WSI.
        tile_coords (np.ndarray): shape [N,4], (row, col, row_end, col_end) at level 0.
        tile_labels (np.ndarray): shape [N], integer labels for each tile.
        level (int): WSI level to visualize.
        downsample_factor (int): Factor for reducing resolution.
        categories (dict): Label -> category name for the legend.
        category_colors (dict): Label -> color mapping.
        output_path (str): Path to save heatmap.

    Returns:
        heatmap (np.ndarray): 2D array at the chosen level resolution.
    """
    # 1) Open the WSI slide
    try:
        slide = openslide.OpenSlide(slide_file_name)
    except Exception as e:
        raise IOError(f"Could not open slide file {slide_file_name}: {e}")
    ## magnification max
    if openslide.PROPERTY_NAME_OBJECTIVE_POWER in slide.properties:
        mag_max = slide.properties[openslide.PROPERTY_NAME_OBJECTIVE_POWER]
        print("mag_max:", mag_max)
        mag_original = mag_max
    else:
        print("[WARNING] mag not found, assuming: {mag_assumed}")
        mag_max = 40
        mag_original = 0

    ## downsample_level
    downsampling = int(int(mag_max)/20)
    print(f"downsampling: {downsampling}")
    
    # 2) Get dimensions at level 0 and chosen level
    px0, py0 = slide.level_dimensions[0]  # Level 0 (original resolution)
    tile_size0 = int(512*downsampling)
    n_rows,n_cols = int(py0/tile_size0), int(px0/tile_size0)

    print(f"n_rows: {n_rows}, n_cols: {n_cols}, total tiles: {n_rows*n_cols}")

    w_level, h_level = slide.level_dimensions[level]  # Chosen level
   
    # 3) Compute scaling factor from level 0 to target level
    scale_x = w_level / px0
    scale_y = h_level / py0

    print(f"Slide level={level} dimensions: {w_level} x {h_level}")
    print(f"Scaling factors - X: {scale_x}, Y: {scale_y}")

    # 4) Create heatmap array (downsample for efficiency)
    w_down, h_down = n_rows // downsample_factor, n_cols // downsample_factor
    heatmap = np.full((h_down, w_down), fill_value=-1, dtype=np.int32)  # Background is -1

    print(f"Created heatmap of shape: {heatmap.shape} (downsampled)")

    # 5) Downscale tile coordinates and place labels
    for i in range(len(tile_labels)):
        row, col, row_end, col_end = tile_coords[i]
        label = tile_labels[i]

        # Scale coordinates to the target level
        row = int(row * scale_y) // downsample_factor
        col = int(col * scale_x) // downsample_factor
        row_end = int(row_end * scale_y) // downsample_factor
        col_end = int(col_end * scale_x) // downsample_factor

        # Ensure bounds stay within the heatmap size
        row_end = min(row_end, h_down)
        col_end = min(col_end, w_down)

        # Fill the heatmap with the corresponding label
        heatmap[row:row_end, col:col_end] = label
    
    slide.close()

    # 6) Define categories and colors
    if categories is None:
        categories = {0: "Neural-crest", 1: "Neuronal", 2: "Photoreceptor", 3: "Proliferative"}
    if category_colors is None:
        category_colors = {0: "red", 1: "green", 2: "blue", 3: "magenta"}

    all_labels = sorted(categories.keys())  # Only valid labels
    label_to_idx = {lbl: idx for idx, lbl in enumerate(all_labels)}

    # Create colormap for labeled areas
    cmap = mcolors.ListedColormap([category_colors[lbl] for lbl in all_labels])
    norm = mcolors.BoundaryNorm(list(range(len(all_labels) + 1)), cmap.N)

    # Mask background (-1 values)
    masked_heatmap = np.ma.masked_where(heatmap == -1, heatmap)

    # 7) Plot heatmap correctly aligned
    fig, ax = plt.subplots(figsize=(10, 10))
    ax.set_facecolor("white")  # Set figure background to white
    ax.imshow(masked_heatmap, cmap=cmap, norm=norm, origin="upper")

    # 8) Add Legend
    legend_elems = [Patch(facecolor=category_colors[lbl], label=categories[lbl]) for lbl in all_labels]
    ax.legend(handles=legend_elems, bbox_to_anchor=(1.05, 1), loc="upper left")

    # Hide axes for clean display
    plt.axis("off")

    # 9) Save image
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    plt.savefig(output_path, bbox_inches="tight", dpi=300, transparent=True)  # Transparent PNG
    plt.close()
    print(f"Saved heatmap to {output_path}")

    return heatmap

# %%
import openslide
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.patches import Patch
import os
import pandas as pd

def create_categorical_heatmap(
    slide_file_name,
    tile_coords,
    tile_labels,
    level=2,
    categories=None,
    category_colors=None,
    output_path="heatmap.png"
):
    """
    Create a categorical heatmap with correctly scaled tiles.

    Args:
        slide_file_name (str): Path to the WSI.
        tile_coordinates_file (str): CSV file containing tile coordinates.
        tile_labels (np.ndarray): shape [N], integer labels for each tile.
        level (int): WSI level to visualize.
        categories (dict): Label -> category name for the legend.
        category_colors (dict): Label -> color mapping.
        output_path (str): Path to save heatmap.

    Returns:
        heatmap (np.ndarray): 2D array at the chosen level resolution.
    """
    # 1) Open the WSI slide
    try:
        slide = openslide.OpenSlide(slide_file_name)
    except Exception as e:
        raise IOError(f"Could not open slide file {slide_file_name}: {e}")

    # 2) Load tile coordinates
    #tile_df = pd.read_csv(tile_coordinates_file)
    
    # Ensure required columns exist
    '''if not {"col", "row", "col_ed", "row_ed"}.issubset(tile_df.columns):
        raise ValueError("CSV file must contain columns: col, row, col_ed, row_ed")'''

    if isinstance(tile_coords, np.ndarray):
        tile_coords = pd.DataFrame(tile_coords, columns=["row", "col", "row_ed", "col_ed"])

    # Extract relevant columns
    tile_coords = tile_coords[["row", "col", "row_ed", "col_ed"]].values

    # 3) Get dimensions at level 0 and chosen level
    w_level0, h_level0 = slide.level_dimensions[0]  # Full resolution
    w_level, h_level = slide.level_dimensions[level]  # Target level resolution

    # 4) Compute scaling factors
    scale_x = w_level / w_level0
    scale_y = h_level / h_level0

    print(f"Slide level={level} dimensions: {w_level} x {h_level}")
    print(f"Scaling factors - X: {scale_x}, Y: {scale_y}")

    # 5) Create heatmap array at the chosen level resolution
    heatmap = np.full((h_level, w_level), fill_value=-1, dtype=np.int32)  # Background as -1

    print(f"Created heatmap of shape: {heatmap.shape}")

    # 6) Properly scale tile coordinates and place labels
    for i in range(len(tile_labels)):
        row, col, row_end, col_end = tile_coords[i]
        label = tile_labels[i]

        # DEBUG: Print original tile coordinates
        print(f"Original Tile {i}: row={row}, col={col}, row_end={row_end}, col_end={col_end}")

        # Scale coordinates using the computed scale factors
        row = int(row * scale_y)
        col = int(col * scale_x)
        row_end = int(row_end * scale_y)
        col_end = int(col_end * scale_x)

        # Ensure bounds stay within the heatmap size
        row = max(0, min(row, h_level - 1))
        col = max(0, min(col, w_level - 1))
        row_end = max(0, min(row_end, h_level))
        col_end = max(0, min(col_end, w_level))

        print(f"Transformed Tile {i}: row={row}, col={col}, row_end={row_end}, col_end={col_end}")

        # Fill the heatmap with the corresponding label
        heatmap[row:row_end, col:col_end] = label
    
    slide.close()

    # 7) Define categories and colors
    if categories is None:
        categories = {0: "Neural-crest", 1: "Neuronal", 2: "Photoreceptor", 3: "Proliferative"}
    if category_colors is None:
        category_colors = {0: "red", 1: "green", 2: "blue", 3: "magenta"}

    all_labels = sorted(categories.keys())  # Only valid labels
    label_to_idx = {lbl: idx for idx, lbl in enumerate(all_labels)}

    # Create colormap for labeled areas
    cmap = mcolors.ListedColormap([category_colors[lbl] for lbl in all_labels])
    norm = mcolors.BoundaryNorm(list(range(len(all_labels) + 1)), cmap.N)

    # Mask background (-1 values)
    masked_heatmap = np.ma.masked_where(heatmap == -1, heatmap)

    # 8) Plot heatmap correctly aligned
    fig, ax = plt.subplots(figsize=(10, 10))
    ax.set_facecolor("white")  # Set figure background to white
    ax.imshow(masked_heatmap, cmap=cmap, norm=norm, origin="upper")

    # 9) Add Legend
    legend_elems = [Patch(facecolor=category_colors[lbl], label=categories[lbl]) for lbl in all_labels]
    ax.legend(handles=legend_elems, bbox_to_anchor=(1.05, 1), loc="upper left")

    # Hide axes for clean display
    plt.axis("off")

    # 10) Save image
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    plt.savefig(output_path, bbox_inches="tight", dpi=300, transparent=True)  # Transparent PNG
    plt.close()
    print(f"Saved heatmap to {output_path}")

    return heatmap

# %%
categories = {
    0: "Neural-crest",
    1: "Neuronal",
    2: "Photoreceptor",
    3: "Proliferative"
}
category_colors = {
    0: "red",
    1: "green",
    2: "blue",
    3: "magenta"
}

# Create the heatmap
heatmap_array = create_categorical_heatmap(
    slide_file_name,
    tile_coords=tile_coords,
    tile_labels=tile_labels,
    level=2,
    categories=categories,
    category_colors=category_colors,
    output_path=os.path.join(outdir,"BM51_categorical_heatmap.png")
)
# Out:
# Slide level=2 dimensions: 22080 x 23232
# Scaling factors - X: 0.25, Y: 0.25
# Created heatmap of shape: (23232, 22080)
# Original Tile 0: row=0, col=0, row_end=720, col_end=64
# Transformed Tile 0: row=0, col=0, row_end=180, col_end=16
# Original Tile 1: row=0, col=0, row_end=736, col_end=64
# Transformed Tile 1: row=0, col=0, row_end=184, col_end=16
# Original Tile 2: row=0, col=0, row_end=752, col_end=64
# Transformed Tile 2: row=0, col=0, row_end=188, col_end=16
# Original Tile 3: row=0, col=0, row_end=768, col_end=64
# Transformed Tile 3: row=0, col=0, row_end=192, col_end=16
# Original Tile 4: row=0, col=0, row_end=640, col_end=80
# Transformed Tile 4: row=0, col=0, row_end=160, col_end=20
# Original Tile 5: row=0, col=0, row_end=656, col_end=80
# Transformed Tile 5: row=0, col=0, row_end=164, col_end=20
# Original Tile 6: row=0, col=0, row_end=672, col_end=80
# Transformed Tile 6: row=0, col=0, row_end=168, col_end=20
# Original Tile 7: row=0, col=0, row_end=688, col_end=80
# Transformed Tile 7: row=0, col=0, row_end=172, col_end=20
# Original Tile 8: row=0, col=0, row_end=704, col_end=80
# Transformed Tile 8: row=0, col=0, row_end=176, col_end=20
# Original Tile 9: row=0, col=0, row_end=720, col_end=80
# Transformed Tile 9: row=0, col=0, row_end=180, col_end=20
# Original Tile 10: row=0, col=0, row_end=736, col_end=80
# Transformed Tile 10: row=0, col=0, row_end=184, col_end=20
# Original Tile 11: row=0, col=0, row_end=752, col_end=80
# Transformed Tile 11: row=0, col=0, row_end=188, col_end=20
# Original Tile 12: row=0, col=0, row_end=768, col_end=80
# Transformed Tile 12: row=0, col=0, row_end=192, col_end=20
# Original Tile 13: row=0, col=0, row_end=608, col_end=96
# Transformed Tile 13: row=0, col=0, row_end=152, col_end=24
# Original Tile 14: row=0, col=0, row_end=624, col_end=96
# Transformed Tile 14: row=0, col=0, row_end=156, col_end=24
# Original Tile 15: row=0, col=0, row_end=640, col_end=96
# Transformed Tile 15: row=0, col=0, row_end=160, col_end=24
# Original Tile 16: row=0, col=0, row_end=656, col_end=96
# Transformed Tile 16: row=0, col=0, row_end=164, col_end=24
# Original Tile 17: row=0, col=0, row_end=672, col_end=96
# Transformed Tile 17: row=0, col=0, row_end=168, col_end=24
# Original Tile 18: row=0, col=0, row_end=688, col_end=96
# Transformed Tile 18: row=0, col=0, row_end=172, col_end=24
# Original Tile 19: row=0, col=0, row_end=704, col_end=96
# Transformed Tile 19: row=0, col=0, row_end=176, col_end=24
# Original Tile 20: row=0, col=0, row_end=720, col_end=96
# Transformed Tile 20: row=0, col=0, row_end=180, col_end=24
# Original Tile 21: row=0, col=0, row_end=736, col_end=96
# Transformed Tile 21: row=0, col=0, row_end=184, col_end=24
# Original Tile 22: row=0, col=0, row_end=752, col_end=96
# Transformed Tile 22: row=0, col=0, row_end=188, col_end=24
# Original Tile 23: row=0, col=0, row_end=768, col_end=96
# Transformed Tile 23: row=0, col=0, row_end=192, col_end=24
# Original Tile 24: row=0, col=0, row_end=576, col_end=112
# Transformed Tile 24: row=0, col=0, row_end=144, col_end=28
# Original Tile 25: row=0, col=0, row_end=592, col_end=112
# Transformed Tile 25: row=0, col=0, row_end=148, col_end=28
# Original Tile 26: row=0, col=0, row_end=608, col_end=112
# Transformed Tile 26: row=0, col=0, row_end=152, col_end=28
# Original Tile 27: row=0, col=0, row_end=624, col_end=112
# Transformed Tile 27: row=0, col=0, row_end=156, col_end=28
# Original Tile 28: row=0, col=0, row_end=640, col_end=112
# Transformed Tile 28: row=0, col=0, row_end=160, col_end=28
# Original Tile 29: row=0, col=0, row_end=656, col_end=112
# Transformed Tile 29: row=0, col=0, row_end=164, col_end=28
# Original Tile 30: row=0, col=0, row_end=672, col_end=112
# Transformed Tile 30: row=0, col=0, row_end=168, col_end=28
# Original Tile 31: row=0, col=0, row_end=688, col_end=112
# Transformed Tile 31: row=0, col=0, row_end=172, col_end=28
# Original Tile 32: row=0, col=0, row_end=704, col_end=112
# Transformed Tile 32: row=0, col=0, row_end=176, col_end=28
# Original Tile 33: row=0, col=0, row_end=720, col_end=112
# Transformed Tile 33: row=0, col=0, row_end=180, col_end=28
# Original Tile 34: row=0, col=0, row_end=736, col_end=112
# Transformed Tile 34: row=0, col=0, row_end=184, col_end=28
# Original Tile 35: row=0, col=0, row_end=752, col_end=112
# Transformed Tile 35: row=0, col=0, row_end=188, col_end=28
# Original Tile 36: row=0, col=0, row_end=768, col_end=112
# Transformed Tile 36: row=0, col=0, row_end=192, col_end=28
# Original Tile 37: row=0, col=0, row_end=832, col_end=112
# Transformed Tile 37: row=0, col=0, row_end=208, col_end=28
# Original Tile 38: row=0, col=0, row_end=848, col_end=112
# Transformed Tile 38: row=0, col=0, row_end=212, col_end=28
# Original Tile 39: row=0, col=0, row_end=864, col_end=112
# Transformed Tile 39: row=0, col=0, row_end=216, col_end=28
# Original Tile 40: row=0, col=0, row_end=544, col_end=128
# Transformed Tile 40: row=0, col=0, row_end=136, col_end=32
# Original Tile 41: row=0, col=0, row_end=560, col_end=128
# Transformed Tile 41: row=0, col=0, row_end=140, col_end=32
# Original Tile 42: row=0, col=0, row_end=576, col_end=128
# Transformed Tile 42: row=0, col=0, row_end=144, col_end=32
# Original Tile 43: row=0, col=0, row_end=592, col_end=128
# Transformed Tile 43: row=0, col=0, row_end=148, col_end=32
# Original Tile 44: row=0, col=0, row_end=608, col_end=128
# Transformed Tile 44: row=0, col=0, row_end=152, col_end=32
# Original Tile 45: row=0, col=0, row_end=624, col_end=128
# Transformed Tile 45: row=0, col=0, row_end=156, col_end=32
# Original Tile 46: row=0, col=0, row_end=640, col_end=128
# Transformed Tile 46: row=0, col=0, row_end=160, col_end=32
# Original Tile 47: row=0, col=0, row_end=656, col_end=128
# Transformed Tile 47: row=0, col=0, row_end=164, col_end=32
# Original Tile 48: row=0, col=0, row_end=672, col_end=128
# Transformed Tile 48: row=0, col=0, row_end=168, col_end=32
# Original Tile 49: row=0, col=0, row_end=688, col_end=128
# Transformed Tile 49: row=0, col=0, row_end=172, col_end=32
# Original Tile 50: row=0, col=0, row_end=704, col_end=128
# Transformed Tile 50: row=0, col=0, row_end=176, col_end=32
# Original Tile 51: row=0, col=0, row_end=720, col_end=128
# Transformed Tile 51: row=0, col=0, row_end=180, col_end=32
# Original Tile 52: row=0, col=0, row_end=736, col_end=128
# Transformed Tile 52: row=0, col=0, row_end=184, col_end=32
# Original Tile 53: row=0, col=0, row_end=752, col_end=128
# Transformed Tile 53: row=0, col=0, row_end=188, col_end=32
# Original Tile 54: row=0, col=0, row_end=768, col_end=128
# Transformed Tile 54: row=0, col=0, row_end=192, col_end=32
# Original Tile 55: row=0, col=0, row_end=816, col_end=128
# Transformed Tile 55: row=0, col=0, row_end=204, col_end=32
# Original Tile 56: row=0, col=0, row_end=832, col_end=128
# Transformed Tile 56: row=0, col=0, row_end=208, col_end=32
# Original Tile 57: row=0, col=0, row_end=848, col_end=128
# Transformed Tile 57: row=0, col=0, row_end=212, col_end=32
# Original Tile 58: row=0, col=0, row_end=864, col_end=128
# Transformed Tile 58: row=0, col=0, row_end=216, col_end=32
# Original Tile 59: row=0, col=0, row_end=880, col_end=128
# Transformed Tile 59: row=0, col=0, row_end=220, col_end=32
# Original Tile 60: row=0, col=0, row_end=896, col_end=128
# Transformed Tile 60: row=0, col=0, row_end=224, col_end=32
# Original Tile 61: row=0, col=0, row_end=912, col_end=128
# Transformed Tile 61: row=0, col=0, row_end=228, col_end=32
# Original Tile 62: row=0, col=0, row_end=528, col_end=144
# Transformed Tile 62: row=0, col=0, row_end=132, col_end=36
# Original Tile 63: row=0, col=0, row_end=544, col_end=144
# Transformed Tile 63: row=0, col=0, row_end=136, col_end=36
# Original Tile 64: row=0, col=0, row_end=576, col_end=144
# Transformed Tile 64: row=0, col=0, row_end=144, col_end=36
# Original Tile 65: row=0, col=0, row_end=592, col_end=144
# Transformed Tile 65: row=0, col=0, row_end=148, col_end=36
# Original Tile 66: row=0, col=0, row_end=608, col_end=144
# Transformed Tile 66: row=0, col=0, row_end=152, col_end=36
# Original Tile 67: row=0, col=0, row_end=624, col_end=144
# Transformed Tile 67: row=0, col=0, row_end=156, col_end=36
# Original Tile 68: row=0, col=0, row_end=640, col_end=144
# Transformed Tile 68: row=0, col=0, row_end=160, col_end=36
# Original Tile 69: row=0, col=0, row_end=656, col_end=144
# Transformed Tile 69: row=0, col=0, row_end=164, col_end=36
# Original Tile 70: row=0, col=0, row_end=672, col_end=144
# Transformed Tile 70: row=0, col=0, row_end=168, col_end=36
# Original Tile 71: row=0, col=0, row_end=688, col_end=144
# Transformed Tile 71: row=0, col=0, row_end=172, col_end=36
# Original Tile 72: row=0, col=0, row_end=704, col_end=144
# Transformed Tile 72: row=0, col=0, row_end=176, col_end=36
# Original Tile 73: row=0, col=0, row_end=720, col_end=144
# Transformed Tile 73: row=0, col=0, row_end=180, col_end=36
# Original Tile 74: row=0, col=0, row_end=736, col_end=144
# Transformed Tile 74: row=0, col=0, row_end=184, col_end=36
# Original Tile 75: row=0, col=0, row_end=752, col_end=144
# Transformed Tile 75: row=0, col=0, row_end=188, col_end=36
# Original Tile 76: row=0, col=0, row_end=768, col_end=144
# Transformed Tile 76: row=0, col=0, row_end=192, col_end=36
# Original Tile 77: row=0, col=0, row_end=816, col_end=144
# Transformed Tile 77: row=0, col=0, row_end=204, col_end=36
# Original Tile 78: row=0, col=0, row_end=832, col_end=144
# Transformed Tile 78: row=0, col=0, row_end=208, col_end=36
# Original Tile 79: row=0, col=0, row_end=848, col_end=144
# Transformed Tile 79: row=0, col=0, row_end=212, col_end=36
# Original Tile 80: row=0, col=0, row_end=864, col_end=144
# Transformed Tile 80: row=0, col=0, row_end=216, col_end=36
# Original Tile 81: row=0, col=0, row_end=880, col_end=144
# Transformed Tile 81: row=0, col=0, row_end=220, col_end=36
# Original Tile 82: row=0, col=0, row_end=896, col_end=144
# Transformed Tile 82: row=0, col=0, row_end=224, col_end=36
# Original Tile 83: row=0, col=0, row_end=912, col_end=144
# Transformed Tile 83: row=0, col=0, row_end=228, col_end=36
# Original Tile 84: row=0, col=0, row_end=928, col_end=144
# Transformed Tile 84: row=0, col=0, row_end=232, col_end=36
# Original Tile 85: row=0, col=0, row_end=528, col_end=160
# Transformed Tile 85: row=0, col=0, row_end=132, col_end=40
# Original Tile 86: row=0, col=0, row_end=544, col_end=160
# Transformed Tile 86: row=0, col=0, row_end=136, col_end=40
# Original Tile 87: row=0, col=0, row_end=560, col_end=160
# Transformed Tile 87: row=0, col=0, row_end=140, col_end=40
# Original Tile 88: row=0, col=0, row_end=576, col_end=160
# Transformed Tile 88: row=0, col=0, row_end=144, col_end=40
# Original Tile 89: row=0, col=0, row_end=592, col_end=160
# Transformed Tile 89: row=0, col=0, row_end=148, col_end=40
# Original Tile 90: row=0, col=0, row_end=608, col_end=160
# Transformed Tile 90: row=0, col=0, row_end=152, col_end=40
# Original Tile 91: row=0, col=0, row_end=624, col_end=160
# Transformed Tile 91: row=0, col=0, row_end=156, col_end=40
# Original Tile 92: row=0, col=0, row_end=640, col_end=160
# Transformed Tile 92: row=0, col=0, row_end=160, col_end=40
# Original Tile 93: row=0, col=0, row_end=656, col_end=160
# Transformed Tile 93: row=0, col=0, row_end=164, col_end=40
# Original Tile 94: row=0, col=0, row_end=672, col_end=160
# Transformed Tile 94: row=0, col=0, row_end=168, col_end=40
# Original Tile 95: row=0, col=0, row_end=688, col_end=160
# Transformed Tile 95: row=0, col=0, row_end=172, col_end=40
# Original Tile 96: row=0, col=0, row_end=704, col_end=160
# Transformed Tile 96: row=0, col=0, row_end=176, col_end=40
# Original Tile 97: row=0, col=0, row_end=720, col_end=160
# Transformed Tile 97: row=0, col=0, row_end=180, col_end=40
# Original Tile 98: row=0, col=0, row_end=736, col_end=160
# Transformed Tile 98: row=0, col=0, row_end=184, col_end=40
# Original Tile 99: row=0, col=0, row_end=752, col_end=160
# Transformed Tile 99: row=0, col=0, row_end=188, col_end=40
# Original Tile 100: row=0, col=0, row_end=768, col_end=160
# Transformed Tile 100: row=0, col=0, row_end=192, col_end=40
# Original Tile 101: row=0, col=0, row_end=800, col_end=160
# Transformed Tile 101: row=0, col=0, row_end=200, col_end=40
# Original Tile 102: row=0, col=0, row_end=816, col_end=160
# Transformed Tile 102: row=0, col=0, row_end=204, col_end=40
# Original Tile 103: row=0, col=0, row_end=832, col_end=160
# Transformed Tile 103: row=0, col=0, row_end=208, col_end=40
# Original Tile 104: row=0, col=0, row_end=848, col_end=160
# Transformed Tile 104: row=0, col=0, row_end=212, col_end=40
# Original Tile 105: row=0, col=0, row_end=864, col_end=160
# Transformed Tile 105: row=0, col=0, row_end=216, col_end=40
# Original Tile 106: row=0, col=0, row_end=880, col_end=160
# Transformed Tile 106: row=0, col=0, row_end=220, col_end=40
# Original Tile 107: row=0, col=0, row_end=896, col_end=160
# Transformed Tile 107: row=0, col=0, row_end=224, col_end=40
# Original Tile 108: row=0, col=0, row_end=912, col_end=160
# Transformed Tile 108: row=0, col=0, row_end=228, col_end=40
# Original Tile 109: row=0, col=0, row_end=928, col_end=160
# Transformed Tile 109: row=0, col=0, row_end=232, col_end=40
# Original Tile 110: row=0, col=0, row_end=944, col_end=160
# Transformed Tile 110: row=0, col=0, row_end=236, col_end=40
# Original Tile 111: row=0, col=0, row_end=960, col_end=160
# Transformed Tile 111: row=0, col=0, row_end=240, col_end=40
# Original Tile 112: row=1, col=0, row_end=1120, col_end=160
# Transformed Tile 112: row=0, col=0, row_end=280, col_end=40
# Original Tile 113: row=1, col=0, row_end=1136, col_end=160
# Transformed Tile 113: row=0, col=0, row_end=284, col_end=40
# Original Tile 114: row=0, col=0, row_end=432, col_end=176
# Transformed Tile 114: row=0, col=0, row_end=108, col_end=44
# Original Tile 115: row=0, col=0, row_end=448, col_end=176
# Transformed Tile 115: row=0, col=0, row_end=112, col_end=44
# Original Tile 116: row=0, col=0, row_end=464, col_end=176
# Transformed Tile 116: row=0, col=0, row_end=116, col_end=44
# Original Tile 117: row=0, col=0, row_end=480, col_end=176
# Transformed Tile 117: row=0, col=0, row_end=120, col_end=44
# Original Tile 118: row=0, col=0, row_end=496, col_end=176
# Transformed Tile 118: row=0, col=0, row_end=124, col_end=44
# Original Tile 119: row=0, col=0, row_end=512, col_end=176
# Transformed Tile 119: row=0, col=0, row_end=128, col_end=44
# Original Tile 120: row=0, col=0, row_end=528, col_end=176
# Transformed Tile 120: row=0, col=0, row_end=132, col_end=44
# Original Tile 121: row=0, col=0, row_end=544, col_end=176
# Transformed Tile 121: row=0, col=0, row_end=136, col_end=44
# Original Tile 122: row=0, col=0, row_end=560, col_end=176
# Transformed Tile 122: row=0, col=0, row_end=140, col_end=44
# Original Tile 123: row=0, col=0, row_end=576, col_end=176
# Transformed Tile 123: row=0, col=0, row_end=144, col_end=44
# Original Tile 124: row=0, col=0, row_end=592, col_end=176
# Transformed Tile 124: row=0, col=0, row_end=148, col_end=44
# Original Tile 125: row=0, col=0, row_end=608, col_end=176
# Transformed Tile 125: row=0, col=0, row_end=152, col_end=44
# Original Tile 126: row=0, col=0, row_end=624, col_end=176
# Transformed Tile 126: row=0, col=0, row_end=156, col_end=44
# Original Tile 127: row=0, col=0, row_end=640, col_end=176
# Transformed Tile 127: row=0, col=0, row_end=160, col_end=44
# Original Tile 128: row=0, col=0, row_end=656, col_end=176
# Transformed Tile 128: row=0, col=0, row_end=164, col_end=44
# Original Tile 129: row=0, col=0, row_end=672, col_end=176
# Transformed Tile 129: row=0, col=0, row_end=168, col_end=44
# Original Tile 130: row=0, col=0, row_end=688, col_end=176
# Transformed Tile 130: row=0, col=0, row_end=172, col_end=44
# Original Tile 131: row=0, col=0, row_end=704, col_end=176
# Transformed Tile 131: row=0, col=0, row_end=176, col_end=44
# Original Tile 132: row=0, col=0, row_end=720, col_end=176
# Transformed Tile 132: row=0, col=0, row_end=180, col_end=44
# Original Tile 133: row=0, col=0, row_end=736, col_end=176
# Transformed Tile 133: row=0, col=0, row_end=184, col_end=44
# Original Tile 134: row=0, col=0, row_end=752, col_end=176
# Transformed Tile 134: row=0, col=0, row_end=188, col_end=44
# Original Tile 135: row=0, col=0, row_end=768, col_end=176
# Transformed Tile 135: row=0, col=0, row_end=192, col_end=44
# Original Tile 136: row=0, col=0, row_end=784, col_end=176
# Transformed Tile 136: row=0, col=0, row_end=196, col_end=44
# Original Tile 137: row=0, col=0, row_end=800, col_end=176
# Transformed Tile 137: row=0, col=0, row_end=200, col_end=44
# Original Tile 138: row=0, col=0, row_end=816, col_end=176
# Transformed Tile 138: row=0, col=0, row_end=204, col_end=44
# Original Tile 139: row=0, col=0, row_end=832, col_end=176
# Transformed Tile 139: row=0, col=0, row_end=208, col_end=44
# Original Tile 140: row=0, col=0, row_end=848, col_end=176
# Transformed Tile 140: row=0, col=0, row_end=212, col_end=44
# Original Tile 141: row=0, col=0, row_end=864, col_end=176
# Transformed Tile 141: row=0, col=0, row_end=216, col_end=44
# Original Tile 142: row=0, col=0, row_end=880, col_end=176
# Transformed Tile 142: row=0, col=0, row_end=220, col_end=44
# Original Tile 143: row=0, col=0, row_end=896, col_end=176
# Transformed Tile 143: row=0, col=0, row_end=224, col_end=44
# Original Tile 144: row=0, col=0, row_end=912, col_end=176
# Transformed Tile 144: row=0, col=0, row_end=228, col_end=44
# Original Tile 145: row=0, col=0, row_end=928, col_end=176
# Transformed Tile 145: row=0, col=0, row_end=232, col_end=44
# Original Tile 146: row=0, col=0, row_end=944, col_end=176
# Transformed Tile 146: row=0, col=0, row_end=236, col_end=44
# Original Tile 147: row=0, col=0, row_end=960, col_end=176
# Transformed Tile 147: row=0, col=0, row_end=240, col_end=44
# Original Tile 148: row=1, col=0, row_end=1104, col_end=176
# Transformed Tile 148: row=0, col=0, row_end=276, col_end=44
# Original Tile 149: row=1, col=0, row_end=1120, col_end=176
# Transformed Tile 149: row=0, col=0, row_end=280, col_end=44
# Original Tile 150: row=1, col=0, row_end=1136, col_end=176
# Transformed Tile 150: row=0, col=0, row_end=284, col_end=44
# Original Tile 151: row=1, col=0, row_end=1152, col_end=176
# Transformed Tile 151: row=0, col=0, row_end=288, col_end=44
# Original Tile 152: row=0, col=0, row_end=400, col_end=192
# Transformed Tile 152: row=0, col=0, row_end=100, col_end=48
# Original Tile 153: row=0, col=0, row_end=416, col_end=192
# Transformed Tile 153: row=0, col=0, row_end=104, col_end=48
# Original Tile 154: row=0, col=0, row_end=432, col_end=192
# Transformed Tile 154: row=0, col=0, row_end=108, col_end=48
# Original Tile 155: row=0, col=0, row_end=448, col_end=192
# Transformed Tile 155: row=0, col=0, row_end=112, col_end=48
# Original Tile 156: row=0, col=0, row_end=464, col_end=192
# Transformed Tile 156: row=0, col=0, row_end=116, col_end=48
# Original Tile 157: row=0, col=0, row_end=480, col_end=192
# Transformed Tile 157: row=0, col=0, row_end=120, col_end=48
# Original Tile 158: row=0, col=0, row_end=496, col_end=192
# Transformed Tile 158: row=0, col=0, row_end=124, col_end=48
# Original Tile 159: row=0, col=0, row_end=512, col_end=192
# Transformed Tile 159: row=0, col=0, row_end=128, col_end=48
# Original Tile 160: row=0, col=0, row_end=528, col_end=192
# Transformed Tile 160: row=0, col=0, row_end=132, col_end=48
# Original Tile 161: row=0, col=0, row_end=544, col_end=192
# Transformed Tile 161: row=0, col=0, row_end=136, col_end=48
# Original Tile 162: row=0, col=0, row_end=560, col_end=192
# Transformed Tile 162: row=0, col=0, row_end=140, col_end=48
# Original Tile 163: row=0, col=0, row_end=576, col_end=192
# Transformed Tile 163: row=0, col=0, row_end=144, col_end=48
# Original Tile 164: row=0, col=0, row_end=592, col_end=192
# Transformed Tile 164: row=0, col=0, row_end=148, col_end=48
# Original Tile 165: row=0, col=0, row_end=608, col_end=192
# Transformed Tile 165: row=0, col=0, row_end=152, col_end=48
# Original Tile 166: row=0, col=0, row_end=624, col_end=192
# Transformed Tile 166: row=0, col=0, row_end=156, col_end=48
# Original Tile 167: row=0, col=0, row_end=640, col_end=192
# Transformed Tile 167: row=0, col=0, row_end=160, col_end=48
# Original Tile 168: row=0, col=0, row_end=656, col_end=192
# Transformed Tile 168: row=0, col=0, row_end=164, col_end=48
# Original Tile 169: row=0, col=0, row_end=672, col_end=192
# Transformed Tile 169: row=0, col=0, row_end=168, col_end=48
# Original Tile 170: row=0, col=0, row_end=688, col_end=192
# Transformed Tile 170: row=0, col=0, row_end=172, col_end=48
# Original Tile 171: row=0, col=0, row_end=704, col_end=192
# Transformed Tile 171: row=0, col=0, row_end=176, col_end=48
# Original Tile 172: row=0, col=0, row_end=720, col_end=192
# Transformed Tile 172: row=0, col=0, row_end=180, col_end=48
# Original Tile 173: row=0, col=0, row_end=736, col_end=192
# Transformed Tile 173: row=0, col=0, row_end=184, col_end=48
# Original Tile 174: row=0, col=0, row_end=752, col_end=192
# Transformed Tile 174: row=0, col=0, row_end=188, col_end=48
# Original Tile 175: row=0, col=0, row_end=768, col_end=192
# Transformed Tile 175: row=0, col=0, row_end=192, col_end=48
# Original Tile 176: row=0, col=0, row_end=784, col_end=192
# Transformed Tile 176: row=0, col=0, row_end=196, col_end=48
# Original Tile 177: row=0, col=0, row_end=800, col_end=192
# Transformed Tile 177: row=0, col=0, row_end=200, col_end=48
# Original Tile 178: row=0, col=0, row_end=816, col_end=192
# Transformed Tile 178: row=0, col=0, row_end=204, col_end=48
# Original Tile 179: row=0, col=0, row_end=832, col_end=192
# Transformed Tile 179: row=0, col=0, row_end=208, col_end=48
# Original Tile 180: row=0, col=0, row_end=848, col_end=192
# Transformed Tile 180: row=0, col=0, row_end=212, col_end=48
# Original Tile 181: row=0, col=0, row_end=864, col_end=192
# Transformed Tile 181: row=0, col=0, row_end=216, col_end=48
# Original Tile 182: row=0, col=0, row_end=880, col_end=192
# Transformed Tile 182: row=0, col=0, row_end=220, col_end=48
# Original Tile 183: row=0, col=0, row_end=896, col_end=192
# Transformed Tile 183: row=0, col=0, row_end=224, col_end=48
# Original Tile 184: row=0, col=0, row_end=912, col_end=192
# Transformed Tile 184: row=0, col=0, row_end=228, col_end=48
# Original Tile 185: row=0, col=0, row_end=928, col_end=192
# Transformed Tile 185: row=0, col=0, row_end=232, col_end=48
# Original Tile 186: row=0, col=0, row_end=944, col_end=192
# Transformed Tile 186: row=0, col=0, row_end=236, col_end=48
# Original Tile 187: row=1, col=0, row_end=1104, col_end=192
# Transformed Tile 187: row=0, col=0, row_end=276, col_end=48
# Original Tile 188: row=1, col=0, row_end=1120, col_end=192
# Transformed Tile 188: row=0, col=0, row_end=280, col_end=48
# Original Tile 189: row=1, col=0, row_end=1136, col_end=192
# Transformed Tile 189: row=0, col=0, row_end=284, col_end=48
# Original Tile 190: row=1, col=0, row_end=1152, col_end=192
# Transformed Tile 190: row=0, col=0, row_end=288, col_end=48
# Original Tile 191: row=0, col=0, row_end=384, col_end=208
# Transformed Tile 191: row=0, col=0, row_end=96, col_end=52
# Original Tile 192: row=0, col=0, row_end=400, col_end=208
# Transformed Tile 192: row=0, col=0, row_end=100, col_end=52
# Original Tile 193: row=0, col=0, row_end=416, col_end=208
# Transformed Tile 193: row=0, col=0, row_end=104, col_end=52
# Original Tile 194: row=0, col=0, row_end=432, col_end=208
# Transformed Tile 194: row=0, col=0, row_end=108, col_end=52
# Original Tile 195: row=0, col=0, row_end=448, col_end=208
# Transformed Tile 195: row=0, col=0, row_end=112, col_end=52
# Original Tile 196: row=0, col=0, row_end=464, col_end=208
# Transformed Tile 196: row=0, col=0, row_end=116, col_end=52
# Original Tile 197: row=0, col=0, row_end=480, col_end=208
# Transformed Tile 197: row=0, col=0, row_end=120, col_end=52
# Original Tile 198: row=0, col=0, row_end=496, col_end=208
# Transformed Tile 198: row=0, col=0, row_end=124, col_end=52
# Original Tile 199: row=0, col=0, row_end=512, col_end=208
# Transformed Tile 199: row=0, col=0, row_end=128, col_end=52
# Original Tile 200: row=0, col=0, row_end=528, col_end=208
# Transformed Tile 200: row=0, col=0, row_end=132, col_end=52
# Original Tile 201: row=0, col=0, row_end=544, col_end=208
# Transformed Tile 201: row=0, col=0, row_end=136, col_end=52
# Original Tile 202: row=0, col=0, row_end=560, col_end=208
# Transformed Tile 202: row=0, col=0, row_end=140, col_end=52
# Original Tile 203: row=0, col=0, row_end=576, col_end=208
# Transformed Tile 203: row=0, col=0, row_end=144, col_end=52
# Original Tile 204: row=0, col=0, row_end=592, col_end=208
# Transformed Tile 204: row=0, col=0, row_end=148, col_end=52
# Original Tile 205: row=0, col=0, row_end=608, col_end=208
# Transformed Tile 205: row=0, col=0, row_end=152, col_end=52
# Original Tile 206: row=0, col=0, row_end=624, col_end=208
# Transformed Tile 206: row=0, col=0, row_end=156, col_end=52
# Original Tile 207: row=0, col=0, row_end=640, col_end=208
# Transformed Tile 207: row=0, col=0, row_end=160, col_end=52
# Original Tile 208: row=0, col=0, row_end=656, col_end=208
# Transformed Tile 208: row=0, col=0, row_end=164, col_end=52
# Original Tile 209: row=0, col=0, row_end=672, col_end=208
# Transformed Tile 209: row=0, col=0, row_end=168, col_end=52
# Original Tile 210: row=0, col=0, row_end=688, col_end=208
# Transformed Tile 210: row=0, col=0, row_end=172, col_end=52
# Original Tile 211: row=0, col=0, row_end=720, col_end=208
# Transformed Tile 211: row=0, col=0, row_end=180, col_end=52
# Original Tile 212: row=0, col=0, row_end=736, col_end=208
# Transformed Tile 212: row=0, col=0, row_end=184, col_end=52
# Original Tile 213: row=0, col=0, row_end=752, col_end=208
# Transformed Tile 213: row=0, col=0, row_end=188, col_end=52
# Original Tile 214: row=0, col=0, row_end=768, col_end=208
# Transformed Tile 214: row=0, col=0, row_end=192, col_end=52
# Original Tile 215: row=0, col=0, row_end=784, col_end=208
# Transformed Tile 215: row=0, col=0, row_end=196, col_end=52
# Original Tile 216: row=0, col=0, row_end=800, col_end=208
# Transformed Tile 216: row=0, col=0, row_end=200, col_end=52
# Original Tile 217: row=0, col=0, row_end=816, col_end=208
# Transformed Tile 217: row=0, col=0, row_end=204, col_end=52
# Original Tile 218: row=0, col=0, row_end=832, col_end=208
# Transformed Tile 218: row=0, col=0, row_end=208, col_end=52
# Original Tile 219: row=0, col=0, row_end=848, col_end=208
# Transformed Tile 219: row=0, col=0, row_end=212, col_end=52
# Original Tile 220: row=0, col=0, row_end=864, col_end=208
# Transformed Tile 220: row=0, col=0, row_end=216, col_end=52
# Original Tile 221: row=0, col=0, row_end=880, col_end=208
# Transformed Tile 221: row=0, col=0, row_end=220, col_end=52
# Original Tile 222: row=0, col=0, row_end=896, col_end=208
# Transformed Tile 222: row=0, col=0, row_end=224, col_end=52
# Original Tile 223: row=0, col=0, row_end=912, col_end=208
# Transformed Tile 223: row=0, col=0, row_end=228, col_end=52
# Original Tile 224: row=0, col=0, row_end=928, col_end=208
# Transformed Tile 224: row=0, col=0, row_end=232, col_end=52
# Original Tile 225: row=0, col=0, row_end=944, col_end=208
# Transformed Tile 225: row=0, col=0, row_end=236, col_end=52
# Original Tile 226: row=1, col=0, row_end=1072, col_end=208
# Transformed Tile 226: row=0, col=0, row_end=268, col_end=52
# Original Tile 227: row=1, col=0, row_end=1088, col_end=208
# Transformed Tile 227: row=0, col=0, row_end=272, col_end=52
# Original Tile 228: row=1, col=0, row_end=1104, col_end=208
# Transformed Tile 228: row=0, col=0, row_end=276, col_end=52
# Original Tile 229: row=1, col=0, row_end=1120, col_end=208
# Transformed Tile 229: row=0, col=0, row_end=280, col_end=52
# Original Tile 230: row=1, col=0, row_end=1168, col_end=208
# Transformed Tile 230: row=0, col=0, row_end=292, col_end=52
# Original Tile 231: row=0, col=0, row_end=368, col_end=224
# Transformed Tile 231: row=0, col=0, row_end=92, col_end=56
# Original Tile 232: row=0, col=0, row_end=384, col_end=224
# Transformed Tile 232: row=0, col=0, row_end=96, col_end=56
# Original Tile 233: row=0, col=0, row_end=400, col_end=224
# Transformed Tile 233: row=0, col=0, row_end=100, col_end=56
# Original Tile 234: row=0, col=0, row_end=416, col_end=224
# Transformed Tile 234: row=0, col=0, row_end=104, col_end=56
# Original Tile 235: row=0, col=0, row_end=432, col_end=224
# Transformed Tile 235: row=0, col=0, row_end=108, col_end=56
# Original Tile 236: row=0, col=0, row_end=448, col_end=224
# Transformed Tile 236: row=0, col=0, row_end=112, col_end=56
# Original Tile 237: row=0, col=0, row_end=464, col_end=224
# Transformed Tile 237: row=0, col=0, row_end=116, col_end=56
# Original Tile 238: row=0, col=0, row_end=480, col_end=224
# Transformed Tile 238: row=0, col=0, row_end=120, col_end=56
# Original Tile 239: row=0, col=0, row_end=496, col_end=224
# Transformed Tile 239: row=0, col=0, row_end=124, col_end=56
# Original Tile 240: row=0, col=0, row_end=512, col_end=224
# Transformed Tile 240: row=0, col=0, row_end=128, col_end=56
# Original Tile 241: row=0, col=0, row_end=528, col_end=224
# Transformed Tile 241: row=0, col=0, row_end=132, col_end=56
# Original Tile 242: row=0, col=0, row_end=544, col_end=224
# Transformed Tile 242: row=0, col=0, row_end=136, col_end=56
# Original Tile 243: row=0, col=0, row_end=560, col_end=224
# Transformed Tile 243: row=0, col=0, row_end=140, col_end=56
# Original Tile 244: row=0, col=0, row_end=576, col_end=224
# Transformed Tile 244: row=0, col=0, row_end=144, col_end=56
# Original Tile 245: row=0, col=0, row_end=592, col_end=224
# Transformed Tile 245: row=0, col=0, row_end=148, col_end=56
# Original Tile 246: row=0, col=0, row_end=608, col_end=224
# Transformed Tile 246: row=0, col=0, row_end=152, col_end=56
# Original Tile 247: row=0, col=0, row_end=624, col_end=224
# Transformed Tile 247: row=0, col=0, row_end=156, col_end=56
# Original Tile 248: row=0, col=0, row_end=640, col_end=224
# Transformed Tile 248: row=0, col=0, row_end=160, col_end=56
# Original Tile 249: row=0, col=0, row_end=656, col_end=224
# Transformed Tile 249: row=0, col=0, row_end=164, col_end=56
# Original Tile 250: row=0, col=0, row_end=672, col_end=224
# Transformed Tile 250: row=0, col=0, row_end=168, col_end=56
# Original Tile 251: row=0, col=0, row_end=688, col_end=224
# Transformed Tile 251: row=0, col=0, row_end=172, col_end=56
# Original Tile 252: row=0, col=0, row_end=704, col_end=224
# Transformed Tile 252: row=0, col=0, row_end=176, col_end=56
# Original Tile 253: row=0, col=0, row_end=720, col_end=224
# Transformed Tile 253: row=0, col=0, row_end=180, col_end=56
# Original Tile 254: row=0, col=0, row_end=736, col_end=224
# Transformed Tile 254: row=0, col=0, row_end=184, col_end=56
# Original Tile 255: row=0, col=0, row_end=752, col_end=224
# Transformed Tile 255: row=0, col=0, row_end=188, col_end=56
# Original Tile 256: row=0, col=0, row_end=768, col_end=224
# Transformed Tile 256: row=0, col=0, row_end=192, col_end=56
# Original Tile 257: row=0, col=0, row_end=784, col_end=224
# Transformed Tile 257: row=0, col=0, row_end=196, col_end=56
# Original Tile 258: row=0, col=0, row_end=800, col_end=224
# Transformed Tile 258: row=0, col=0, row_end=200, col_end=56
# Original Tile 259: row=0, col=0, row_end=816, col_end=224
# Transformed Tile 259: row=0, col=0, row_end=204, col_end=56
# Original Tile 260: row=0, col=0, row_end=832, col_end=224
# Transformed Tile 260: row=0, col=0, row_end=208, col_end=56
# Original Tile 261: row=0, col=0, row_end=848, col_end=224
# Transformed Tile 261: row=0, col=0, row_end=212, col_end=56
# Original Tile 262: row=0, col=0, row_end=864, col_end=224
# Transformed Tile 262: row=0, col=0, row_end=216, col_end=56
# Original Tile 263: row=0, col=0, row_end=880, col_end=224
# Transformed Tile 263: row=0, col=0, row_end=220, col_end=56
# Original Tile 264: row=0, col=0, row_end=896, col_end=224
# Transformed Tile 264: row=0, col=0, row_end=224, col_end=56
# Original Tile 265: row=0, col=0, row_end=912, col_end=224
# Transformed Tile 265: row=0, col=0, row_end=228, col_end=56
# Original Tile 266: row=0, col=0, row_end=928, col_end=224
# Transformed Tile 266: row=0, col=0, row_end=232, col_end=56
# Original Tile 267: row=0, col=0, row_end=992, col_end=224
# Transformed Tile 267: row=0, col=0, row_end=248, col_end=56
# Original Tile 268: row=1, col=0, row_end=1040, col_end=224
# Transformed Tile 268: row=0, col=0, row_end=260, col_end=56
# Original Tile 269: row=1, col=0, row_end=1056, col_end=224
# Transformed Tile 269: row=0, col=0, row_end=264, col_end=56
# Original Tile 270: row=1, col=0, row_end=1072, col_end=224
# Transformed Tile 270: row=0, col=0, row_end=268, col_end=56
# Original Tile 271: row=1, col=0, row_end=1088, col_end=224
# Transformed Tile 271: row=0, col=0, row_end=272, col_end=56
# Original Tile 272: row=1, col=0, row_end=1104, col_end=224
# Transformed Tile 272: row=0, col=0, row_end=276, col_end=56
# Original Tile 273: row=1, col=0, row_end=1120, col_end=224
# Transformed Tile 273: row=0, col=0, row_end=280, col_end=56
# Original Tile 274: row=1, col=0, row_end=1136, col_end=224
# Transformed Tile 274: row=0, col=0, row_end=284, col_end=56
# Original Tile 275: row=1, col=0, row_end=1168, col_end=224
# Transformed Tile 275: row=0, col=0, row_end=292, col_end=56
# Original Tile 276: row=0, col=0, row_end=352, col_end=240
# Transformed Tile 276: row=0, col=0, row_end=88, col_end=60
# Original Tile 277: row=0, col=0, row_end=368, col_end=240
# Transformed Tile 277: row=0, col=0, row_end=92, col_end=60
# Original Tile 278: row=0, col=0, row_end=384, col_end=240
# Transformed Tile 278: row=0, col=0, row_end=96, col_end=60
# Original Tile 279: row=0, col=0, row_end=400, col_end=240
# Transformed Tile 279: row=0, col=0, row_end=100, col_end=60
# Original Tile 280: row=0, col=0, row_end=416, col_end=240
# Transformed Tile 280: row=0, col=0, row_end=104, col_end=60
# Original Tile 281: row=0, col=0, row_end=432, col_end=240
# Transformed Tile 281: row=0, col=0, row_end=108, col_end=60
# Original Tile 282: row=0, col=0, row_end=448, col_end=240
# Transformed Tile 282: row=0, col=0, row_end=112, col_end=60
# Original Tile 283: row=0, col=0, row_end=464, col_end=240
# Transformed Tile 283: row=0, col=0, row_end=116, col_end=60
# Original Tile 284: row=0, col=0, row_end=480, col_end=240
# Transformed Tile 284: row=0, col=0, row_end=120, col_end=60
# Original Tile 285: row=0, col=0, row_end=496, col_end=240
# Transformed Tile 285: row=0, col=0, row_end=124, col_end=60
# Original Tile 286: row=0, col=0, row_end=512, col_end=240
# Transformed Tile 286: row=0, col=0, row_end=128, col_end=60
# Original Tile 287: row=0, col=0, row_end=528, col_end=240
# Transformed Tile 287: row=0, col=0, row_end=132, col_end=60
# Original Tile 288: row=0, col=0, row_end=544, col_end=240
# Transformed Tile 288: row=0, col=0, row_end=136, col_end=60
# Original Tile 289: row=0, col=0, row_end=560, col_end=240
# Transformed Tile 289: row=0, col=0, row_end=140, col_end=60
# Original Tile 290: row=0, col=0, row_end=576, col_end=240
# Transformed Tile 290: row=0, col=0, row_end=144, col_end=60
# Original Tile 291: row=0, col=0, row_end=592, col_end=240
# Transformed Tile 291: row=0, col=0, row_end=148, col_end=60
# Original Tile 292: row=0, col=0, row_end=608, col_end=240
# Transformed Tile 292: row=0, col=0, row_end=152, col_end=60
# Original Tile 293: row=0, col=0, row_end=624, col_end=240
# Transformed Tile 293: row=0, col=0, row_end=156, col_end=60
# Original Tile 294: row=0, col=0, row_end=640, col_end=240
# Transformed Tile 294: row=0, col=0, row_end=160, col_end=60
# Original Tile 295: row=0, col=0, row_end=656, col_end=240
# Transformed Tile 295: row=0, col=0, row_end=164, col_end=60
# Original Tile 296: row=0, col=0, row_end=672, col_end=240
# Transformed Tile 296: row=0, col=0, row_end=168, col_end=60
# Original Tile 297: row=0, col=0, row_end=688, col_end=240
# Transformed Tile 297: row=0, col=0, row_end=172, col_end=60
# Original Tile 298: row=0, col=0, row_end=704, col_end=240
# Transformed Tile 298: row=0, col=0, row_end=176, col_end=60
# Original Tile 299: row=0, col=0, row_end=720, col_end=240
# Transformed Tile 299: row=0, col=0, row_end=180, col_end=60
# Original Tile 300: row=0, col=0, row_end=736, col_end=240
# Transformed Tile 300: row=0, col=0, row_end=184, col_end=60
# Original Tile 301: row=0, col=0, row_end=752, col_end=240
# Transformed Tile 301: row=0, col=0, row_end=188, col_end=60
# Original Tile 302: row=0, col=0, row_end=768, col_end=240
# Transformed Tile 302: row=0, col=0, row_end=192, col_end=60
# Original Tile 303: row=0, col=0, row_end=784, col_end=240
# Transformed Tile 303: row=0, col=0, row_end=196, col_end=60
# Original Tile 304: row=0, col=0, row_end=800, col_end=240
# Transformed Tile 304: row=0, col=0, row_end=200, col_end=60
# Original Tile 305: row=0, col=0, row_end=816, col_end=240
# Transformed Tile 305: row=0, col=0, row_end=204, col_end=60
# Original Tile 306: row=0, col=0, row_end=832, col_end=240
# Transformed Tile 306: row=0, col=0, row_end=208, col_end=60
# Original Tile 307: row=0, col=0, row_end=848, col_end=240
# Transformed Tile 307: row=0, col=0, row_end=212, col_end=60
# Original Tile 308: row=0, col=0, row_end=864, col_end=240
# Transformed Tile 308: row=0, col=0, row_end=216, col_end=60
# Original Tile 309: row=0, col=0, row_end=880, col_end=240
# Transformed Tile 309: row=0, col=0, row_end=220, col_end=60
# Original Tile 310: row=0, col=0, row_end=896, col_end=240
# Transformed Tile 310: row=0, col=0, row_end=224, col_end=60
# Original Tile 311: row=0, col=0, row_end=912, col_end=240
# Transformed Tile 311: row=0, col=0, row_end=228, col_end=60
# Original Tile 312: row=0, col=0, row_end=928, col_end=240
# Transformed Tile 312: row=0, col=0, row_end=232, col_end=60
# Original Tile 313: row=0, col=0, row_end=944, col_end=240
# Transformed Tile 313: row=0, col=0, row_end=236, col_end=60
# Original Tile 314: row=0, col=0, row_end=960, col_end=240
# Transformed Tile 314: row=0, col=0, row_end=240, col_end=60
# Original Tile 315: row=0, col=0, row_end=976, col_end=240
# Transformed Tile 315: row=0, col=0, row_end=244, col_end=60
# Original Tile 316: row=0, col=0, row_end=992, col_end=240
# Transformed Tile 316: row=0, col=0, row_end=248, col_end=60
# Original Tile 317: row=0, col=0, row_end=1008, col_end=240
# Transformed Tile 317: row=0, col=0, row_end=252, col_end=60
# Original Tile 318: row=1, col=0, row_end=1024, col_end=240
# Transformed Tile 318: row=0, col=0, row_end=256, col_end=60
# Original Tile 319: row=1, col=0, row_end=1056, col_end=240
# Transformed Tile 319: row=0, col=0, row_end=264, col_end=60
# Original Tile 320: row=1, col=0, row_end=1072, col_end=240
# Transformed Tile 320: row=0, col=0, row_end=268, col_end=60
# Original Tile 321: row=1, col=0, row_end=1088, col_end=240
# Transformed Tile 321: row=0, col=0, row_end=272, col_end=60
# Original Tile 322: row=1, col=0, row_end=1104, col_end=240
# Transformed Tile 322: row=0, col=0, row_end=276, col_end=60
# Original Tile 323: row=1, col=0, row_end=1120, col_end=240
# Transformed Tile 323: row=0, col=0, row_end=280, col_end=60
# Original Tile 324: row=1, col=0, row_end=1136, col_end=240
# Transformed Tile 324: row=0, col=0, row_end=284, col_end=60
# Original Tile 325: row=1, col=0, row_end=1152, col_end=240
# Transformed Tile 325: row=0, col=0, row_end=288, col_end=60
# Original Tile 326: row=1, col=0, row_end=1168, col_end=240
# Transformed Tile 326: row=0, col=0, row_end=292, col_end=60
# Original Tile 327: row=0, col=0, row_end=352, col_end=256
# Transformed Tile 327: row=0, col=0, row_end=88, col_end=64
# Original Tile 328: row=0, col=0, row_end=368, col_end=256
# Transformed Tile 328: row=0, col=0, row_end=92, col_end=64
# Original Tile 329: row=0, col=0, row_end=384, col_end=256
# Transformed Tile 329: row=0, col=0, row_end=96, col_end=64
# Original Tile 330: row=0, col=0, row_end=400, col_end=256
# Transformed Tile 330: row=0, col=0, row_end=100, col_end=64
# Original Tile 331: row=0, col=0, row_end=416, col_end=256
# Transformed Tile 331: row=0, col=0, row_end=104, col_end=64
# Original Tile 332: row=0, col=0, row_end=432, col_end=256
# Transformed Tile 332: row=0, col=0, row_end=108, col_end=64
# Original Tile 333: row=0, col=0, row_end=448, col_end=256
# Transformed Tile 333: row=0, col=0, row_end=112, col_end=64
# Original Tile 334: row=0, col=0, row_end=464, col_end=256
# Transformed Tile 334: row=0, col=0, row_end=116, col_end=64
# Original Tile 335: row=0, col=0, row_end=480, col_end=256
# Transformed Tile 335: row=0, col=0, row_end=120, col_end=64
# Original Tile 336: row=0, col=0, row_end=496, col_end=256
# Transformed Tile 336: row=0, col=0, row_end=124, col_end=64
# Original Tile 337: row=0, col=0, row_end=512, col_end=256
# Transformed Tile 337: row=0, col=0, row_end=128, col_end=64
# Original Tile 338: row=0, col=0, row_end=528, col_end=256
# Transformed Tile 338: row=0, col=0, row_end=132, col_end=64
# Original Tile 339: row=0, col=0, row_end=544, col_end=256
# Transformed Tile 339: row=0, col=0, row_end=136, col_end=64
# Original Tile 340: row=0, col=0, row_end=560, col_end=256
# Transformed Tile 340: row=0, col=0, row_end=140, col_end=64
# Original Tile 341: row=0, col=0, row_end=576, col_end=256
# Transformed Tile 341: row=0, col=0, row_end=144, col_end=64
# Original Tile 342: row=0, col=0, row_end=592, col_end=256
# Transformed Tile 342: row=0, col=0, row_end=148, col_end=64
# Original Tile 343: row=0, col=0, row_end=608, col_end=256
# Transformed Tile 343: row=0, col=0, row_end=152, col_end=64
# Original Tile 344: row=0, col=0, row_end=624, col_end=256
# Transformed Tile 344: row=0, col=0, row_end=156, col_end=64
# Original Tile 345: row=0, col=0, row_end=640, col_end=256
# Transformed Tile 345: row=0, col=0, row_end=160, col_end=64
# Original Tile 346: row=0, col=0, row_end=656, col_end=256
# Transformed Tile 346: row=0, col=0, row_end=164, col_end=64
# Original Tile 347: row=0, col=0, row_end=672, col_end=256
# Transformed Tile 347: row=0, col=0, row_end=168, col_end=64
# Original Tile 348: row=0, col=0, row_end=688, col_end=256
# Transformed Tile 348: row=0, col=0, row_end=172, col_end=64
# Original Tile 349: row=0, col=0, row_end=704, col_end=256
# Transformed Tile 349: row=0, col=0, row_end=176, col_end=64
# Original Tile 350: row=0, col=0, row_end=720, col_end=256
# Transformed Tile 350: row=0, col=0, row_end=180, col_end=64
# Original Tile 351: row=0, col=0, row_end=736, col_end=256
# Transformed Tile 351: row=0, col=0, row_end=184, col_end=64
# Original Tile 352: row=0, col=0, row_end=752, col_end=256
# Transformed Tile 352: row=0, col=0, row_end=188, col_end=64
# Original Tile 353: row=0, col=0, row_end=768, col_end=256
# Transformed Tile 353: row=0, col=0, row_end=192, col_end=64
# Original Tile 354: row=0, col=0, row_end=784, col_end=256
# Transformed Tile 354: row=0, col=0, row_end=196, col_end=64
# Original Tile 355: row=0, col=0, row_end=800, col_end=256
# Transformed Tile 355: row=0, col=0, row_end=200, col_end=64
# Original Tile 356: row=0, col=0, row_end=816, col_end=256
# Transformed Tile 356: row=0, col=0, row_end=204, col_end=64
# Original Tile 357: row=0, col=0, row_end=832, col_end=256
# Transformed Tile 357: row=0, col=0, row_end=208, col_end=64
# Original Tile 358: row=0, col=0, row_end=848, col_end=256
# Transformed Tile 358: row=0, col=0, row_end=212, col_end=64
# Original Tile 359: row=0, col=0, row_end=864, col_end=256
# Transformed Tile 359: row=0, col=0, row_end=216, col_end=64
# Original Tile 360: row=0, col=0, row_end=880, col_end=256
# Transformed Tile 360: row=0, col=0, row_end=220, col_end=64
# Original Tile 361: row=0, col=0, row_end=896, col_end=256
# Transformed Tile 361: row=0, col=0, row_end=224, col_end=64
# Original Tile 362: row=0, col=0, row_end=912, col_end=256
# Transformed Tile 362: row=0, col=0, row_end=228, col_end=64
# Original Tile 363: row=0, col=0, row_end=928, col_end=256
# Transformed Tile 363: row=0, col=0, row_end=232, col_end=64
# Original Tile 364: row=0, col=0, row_end=944, col_end=256
# Transformed Tile 364: row=0, col=0, row_end=236, col_end=64
# Original Tile 365: row=0, col=0, row_end=960, col_end=256
# Transformed Tile 365: row=0, col=0, row_end=240, col_end=64
# Original Tile 366: row=0, col=0, row_end=976, col_end=256
# Transformed Tile 366: row=0, col=0, row_end=244, col_end=64
# Original Tile 367: row=0, col=0, row_end=992, col_end=256
# Transformed Tile 367: row=0, col=0, row_end=248, col_end=64
# Original Tile 368: row=0, col=0, row_end=1008, col_end=256
# Transformed Tile 368: row=0, col=0, row_end=252, col_end=64
# Original Tile 369: row=1, col=0, row_end=1024, col_end=256
# Transformed Tile 369: row=0, col=0, row_end=256, col_end=64
# Original Tile 370: row=1, col=0, row_end=1056, col_end=256
# Transformed Tile 370: row=0, col=0, row_end=264, col_end=64
# Original Tile 371: row=1, col=0, row_end=1072, col_end=256
# Transformed Tile 371: row=0, col=0, row_end=268, col_end=64
# Original Tile 372: row=1, col=0, row_end=1088, col_end=256
# Transformed Tile 372: row=0, col=0, row_end=272, col_end=64
# Original Tile 373: row=1, col=0, row_end=1104, col_end=256
# Transformed Tile 373: row=0, col=0, row_end=276, col_end=64
# Original Tile 374: row=1, col=0, row_end=1120, col_end=256
# Transformed Tile 374: row=0, col=0, row_end=280, col_end=64
# Original Tile 375: row=1, col=0, row_end=1136, col_end=256
# Transformed Tile 375: row=0, col=0, row_end=284, col_end=64
# Original Tile 376: row=1, col=0, row_end=1152, col_end=256
# Transformed Tile 376: row=0, col=0, row_end=288, col_end=64
# Original Tile 377: row=1, col=0, row_end=1168, col_end=256
# Transformed Tile 377: row=0, col=0, row_end=292, col_end=64
# Original Tile 378: row=1, col=0, row_end=1184, col_end=256
# Transformed Tile 378: row=0, col=0, row_end=296, col_end=64
# Original Tile 379: row=0, col=0, row_end=336, col_end=272
# Transformed Tile 379: row=0, col=0, row_end=84, col_end=68
# Original Tile 380: row=0, col=0, row_end=352, col_end=272
# Transformed Tile 380: row=0, col=0, row_end=88, col_end=68
# Original Tile 381: row=0, col=0, row_end=368, col_end=272
# Transformed Tile 381: row=0, col=0, row_end=92, col_end=68
# Original Tile 382: row=0, col=0, row_end=384, col_end=272
# Transformed Tile 382: row=0, col=0, row_end=96, col_end=68
# Original Tile 383: row=0, col=0, row_end=400, col_end=272
# Transformed Tile 383: row=0, col=0, row_end=100, col_end=68
# Original Tile 384: row=0, col=0, row_end=416, col_end=272
# Transformed Tile 384: row=0, col=0, row_end=104, col_end=68
# Original Tile 385: row=0, col=0, row_end=432, col_end=272
# Transformed Tile 385: row=0, col=0, row_end=108, col_end=68
# Original Tile 386: row=0, col=0, row_end=448, col_end=272
# Transformed Tile 386: row=0, col=0, row_end=112, col_end=68
# Original Tile 387: row=0, col=0, row_end=464, col_end=272
# Transformed Tile 387: row=0, col=0, row_end=116, col_end=68
# Original Tile 388: row=0, col=0, row_end=480, col_end=272
# Transformed Tile 388: row=0, col=0, row_end=120, col_end=68
# Original Tile 389: row=0, col=0, row_end=496, col_end=272
# Transformed Tile 389: row=0, col=0, row_end=124, col_end=68
# Original Tile 390: row=0, col=0, row_end=512, col_end=272
# Transformed Tile 390: row=0, col=0, row_end=128, col_end=68
# Original Tile 391: row=0, col=0, row_end=528, col_end=272
# Transformed Tile 391: row=0, col=0, row_end=132, col_end=68
# Original Tile 392: row=0, col=0, row_end=544, col_end=272
# Transformed Tile 392: row=0, col=0, row_end=136, col_end=68
# Original Tile 393: row=0, col=0, row_end=560, col_end=272
# Transformed Tile 393: row=0, col=0, row_end=140, col_end=68
# Original Tile 394: row=0, col=0, row_end=576, col_end=272
# Transformed Tile 394: row=0, col=0, row_end=144, col_end=68
# Original Tile 395: row=0, col=0, row_end=592, col_end=272
# Transformed Tile 395: row=0, col=0, row_end=148, col_end=68
# Original Tile 396: row=0, col=0, row_end=608, col_end=272
# Transformed Tile 396: row=0, col=0, row_end=152, col_end=68
# Original Tile 397: row=0, col=0, row_end=624, col_end=272
# Transformed Tile 397: row=0, col=0, row_end=156, col_end=68
# Original Tile 398: row=0, col=0, row_end=640, col_end=272
# Transformed Tile 398: row=0, col=0, row_end=160, col_end=68
# Original Tile 399: row=0, col=0, row_end=656, col_end=272
# Transformed Tile 399: row=0, col=0, row_end=164, col_end=68
# Original Tile 400: row=0, col=0, row_end=672, col_end=272
# Transformed Tile 400: row=0, col=0, row_end=168, col_end=68
# Original Tile 401: row=0, col=0, row_end=688, col_end=272
# Transformed Tile 401: row=0, col=0, row_end=172, col_end=68
# Original Tile 402: row=0, col=0, row_end=704, col_end=272
# Transformed Tile 402: row=0, col=0, row_end=176, col_end=68
# Original Tile 403: row=0, col=0, row_end=720, col_end=272
# Transformed Tile 403: row=0, col=0, row_end=180, col_end=68
# Original Tile 404: row=0, col=0, row_end=736, col_end=272
# Transformed Tile 404: row=0, col=0, row_end=184, col_end=68
# Original Tile 405: row=0, col=0, row_end=752, col_end=272
# Transformed Tile 405: row=0, col=0, row_end=188, col_end=68
# Original Tile 406: row=0, col=0, row_end=768, col_end=272
# Transformed Tile 406: row=0, col=0, row_end=192, col_end=68
# Original Tile 407: row=0, col=0, row_end=784, col_end=272
# ...
# Original Tile 2876: row=0, col=1, row_end=864, col_end=1248
# Transformed Tile 2876: row=0, col=0, row_end=216, col_end=312
# Original Tile 2877: row=0, col=1, row_end=880, col_end=1248
# Transformed Tile 2877: row=0, col=0, row_end=220, col_end=312
# Original Tile 2878: row=0, col=1, row_end=896, col_end=1248
# Transformed Tile 2878: row=0, col=0, row_end=224, col_end=312
# Original Tile 2879: row=0, col=1, row_end=912, col_end=1248
# Transformed Tile 2879: row=0, col=0, row_end=228, col_end=312
# Original Tile 2880: row=0, col=1, row_end=928, col_end=1248
# Transformed Tile 2880: row=0, col=0, row_end=232, col_end=312
# Original Tile 2881: row=0, col=1, row_end=944, col_end=1248
# Transformed Tile 2881: row=0, col=0, row_end=236, col_end=312
# Original Tile 2882: row=0, col=1, row_end=960, col_end=1248
# Transformed Tile 2882: row=0, col=0, row_end=240, col_end=312
# Original Tile 2883: row=1, col=1, row_end=1040, col_end=1248
# Transformed Tile 2883: row=0, col=0, row_end=260, col_end=312
# Original Tile 2884: row=0, col=1, row_end=656, col_end=1264
# Transformed Tile 2884: row=0, col=0, row_end=164, col_end=316
# Original Tile 2885: row=0, col=1, row_end=672, col_end=1264
# Transformed Tile 2885: row=0, col=0, row_end=168, col_end=316
# Original Tile 2886: row=0, col=1, row_end=688, col_end=1264
# Transformed Tile 2886: row=0, col=0, row_end=172, col_end=316
# Original Tile 2887: row=0, col=1, row_end=704, col_end=1264
# Transformed Tile 2887: row=0, col=0, row_end=176, col_end=316
# Original Tile 2888: row=0, col=1, row_end=720, col_end=1264
# Transformed Tile 2888: row=0, col=0, row_end=180, col_end=316
# Original Tile 2889: row=0, col=1, row_end=736, col_end=1264
# Transformed Tile 2889: row=0, col=0, row_end=184, col_end=316
# Original Tile 2890: row=0, col=1, row_end=752, col_end=1264
# Transformed Tile 2890: row=0, col=0, row_end=188, col_end=316
# Original Tile 2891: row=0, col=1, row_end=768, col_end=1264
# Transformed Tile 2891: row=0, col=0, row_end=192, col_end=316
# Original Tile 2892: row=0, col=1, row_end=784, col_end=1264
# Transformed Tile 2892: row=0, col=0, row_end=196, col_end=316
# Original Tile 2893: row=0, col=1, row_end=800, col_end=1264
# Transformed Tile 2893: row=0, col=0, row_end=200, col_end=316
# Original Tile 2894: row=0, col=1, row_end=816, col_end=1264
# Transformed Tile 2894: row=0, col=0, row_end=204, col_end=316
# Original Tile 2895: row=0, col=1, row_end=832, col_end=1264
# Transformed Tile 2895: row=0, col=0, row_end=208, col_end=316
# Original Tile 2896: row=0, col=1, row_end=848, col_end=1264
# Transformed Tile 2896: row=0, col=0, row_end=212, col_end=316
# Original Tile 2897: row=0, col=1, row_end=864, col_end=1264
# Transformed Tile 2897: row=0, col=0, row_end=216, col_end=316
# Original Tile 2898: row=0, col=1, row_end=880, col_end=1264
# Transformed Tile 2898: row=0, col=0, row_end=220, col_end=316
# Original Tile 2899: row=0, col=1, row_end=896, col_end=1264
# Transformed Tile 2899: row=0, col=0, row_end=224, col_end=316
# Original Tile 2900: row=0, col=1, row_end=912, col_end=1264
# Transformed Tile 2900: row=0, col=0, row_end=228, col_end=316
# Original Tile 2901: row=0, col=1, row_end=928, col_end=1264
# Transformed Tile 2901: row=0, col=0, row_end=232, col_end=316
# Original Tile 2902: row=0, col=1, row_end=944, col_end=1264
# Transformed Tile 2902: row=0, col=0, row_end=236, col_end=316
# Original Tile 2903: row=0, col=1, row_end=640, col_end=1280
# Transformed Tile 2903: row=0, col=0, row_end=160, col_end=320
# Original Tile 2904: row=0, col=1, row_end=656, col_end=1280
# Transformed Tile 2904: row=0, col=0, row_end=164, col_end=320
# Original Tile 2905: row=0, col=1, row_end=672, col_end=1280
# Transformed Tile 2905: row=0, col=0, row_end=168, col_end=320
# Original Tile 2906: row=0, col=1, row_end=688, col_end=1280
# Transformed Tile 2906: row=0, col=0, row_end=172, col_end=320
# Original Tile 2907: row=0, col=1, row_end=704, col_end=1280
# Transformed Tile 2907: row=0, col=0, row_end=176, col_end=320
# Original Tile 2908: row=0, col=1, row_end=720, col_end=1280
# Transformed Tile 2908: row=0, col=0, row_end=180, col_end=320
# Original Tile 2909: row=0, col=1, row_end=736, col_end=1280
# Transformed Tile 2909: row=0, col=0, row_end=184, col_end=320
# Original Tile 2910: row=0, col=1, row_end=752, col_end=1280
# Transformed Tile 2910: row=0, col=0, row_end=188, col_end=320
# Original Tile 2911: row=0, col=1, row_end=768, col_end=1280
# Transformed Tile 2911: row=0, col=0, row_end=192, col_end=320
# Original Tile 2912: row=0, col=1, row_end=784, col_end=1280
# Transformed Tile 2912: row=0, col=0, row_end=196, col_end=320
# Original Tile 2913: row=0, col=1, row_end=800, col_end=1280
# Transformed Tile 2913: row=0, col=0, row_end=200, col_end=320
# Original Tile 2914: row=0, col=1, row_end=816, col_end=1280
# Transformed Tile 2914: row=0, col=0, row_end=204, col_end=320
# Original Tile 2915: row=0, col=1, row_end=832, col_end=1280
# Transformed Tile 2915: row=0, col=0, row_end=208, col_end=320
# Original Tile 2916: row=0, col=1, row_end=848, col_end=1280
# Transformed Tile 2916: row=0, col=0, row_end=212, col_end=320
# Original Tile 2917: row=0, col=1, row_end=864, col_end=1280
# Transformed Tile 2917: row=0, col=0, row_end=216, col_end=320
# Original Tile 2918: row=0, col=1, row_end=880, col_end=1280
# Transformed Tile 2918: row=0, col=0, row_end=220, col_end=320
# Original Tile 2919: row=0, col=1, row_end=896, col_end=1280
# Transformed Tile 2919: row=0, col=0, row_end=224, col_end=320
# Original Tile 2920: row=0, col=1, row_end=912, col_end=1280
# Transformed Tile 2920: row=0, col=0, row_end=228, col_end=320
# Original Tile 2921: row=0, col=1, row_end=928, col_end=1280
# Transformed Tile 2921: row=0, col=0, row_end=232, col_end=320
# Original Tile 2922: row=0, col=1, row_end=944, col_end=1280
# Transformed Tile 2922: row=0, col=0, row_end=236, col_end=320
# Original Tile 2923: row=0, col=1, row_end=640, col_end=1296
# Transformed Tile 2923: row=0, col=0, row_end=160, col_end=324
# Original Tile 2924: row=0, col=1, row_end=656, col_end=1296
# Transformed Tile 2924: row=0, col=0, row_end=164, col_end=324
# Original Tile 2925: row=0, col=1, row_end=672, col_end=1296
# Transformed Tile 2925: row=0, col=0, row_end=168, col_end=324
# Original Tile 2926: row=0, col=1, row_end=688, col_end=1296
# Transformed Tile 2926: row=0, col=0, row_end=172, col_end=324
# Original Tile 2927: row=0, col=1, row_end=704, col_end=1296
# Transformed Tile 2927: row=0, col=0, row_end=176, col_end=324
# Original Tile 2928: row=0, col=1, row_end=720, col_end=1296
# Transformed Tile 2928: row=0, col=0, row_end=180, col_end=324
# Original Tile 2929: row=0, col=1, row_end=736, col_end=1296
# Transformed Tile 2929: row=0, col=0, row_end=184, col_end=324
# Original Tile 2930: row=0, col=1, row_end=752, col_end=1296
# Transformed Tile 2930: row=0, col=0, row_end=188, col_end=324
# Original Tile 2931: row=0, col=1, row_end=768, col_end=1296
# Transformed Tile 2931: row=0, col=0, row_end=192, col_end=324
# Original Tile 2932: row=0, col=1, row_end=784, col_end=1296
# Transformed Tile 2932: row=0, col=0, row_end=196, col_end=324
# Original Tile 2933: row=0, col=1, row_end=800, col_end=1296
# Transformed Tile 2933: row=0, col=0, row_end=200, col_end=324
# Original Tile 2934: row=0, col=1, row_end=816, col_end=1296
# Transformed Tile 2934: row=0, col=0, row_end=204, col_end=324
# Original Tile 2935: row=0, col=1, row_end=832, col_end=1296
# Transformed Tile 2935: row=0, col=0, row_end=208, col_end=324
# Original Tile 2936: row=0, col=1, row_end=848, col_end=1296
# Transformed Tile 2936: row=0, col=0, row_end=212, col_end=324
# Original Tile 2937: row=0, col=1, row_end=864, col_end=1296
# Transformed Tile 2937: row=0, col=0, row_end=216, col_end=324
# Original Tile 2938: row=0, col=1, row_end=880, col_end=1296
# Transformed Tile 2938: row=0, col=0, row_end=220, col_end=324
# Original Tile 2939: row=0, col=1, row_end=896, col_end=1296
# Transformed Tile 2939: row=0, col=0, row_end=224, col_end=324
# Original Tile 2940: row=0, col=1, row_end=912, col_end=1296
# Transformed Tile 2940: row=0, col=0, row_end=228, col_end=324
# Original Tile 2941: row=0, col=1, row_end=640, col_end=1312
# Transformed Tile 2941: row=0, col=0, row_end=160, col_end=328
# Original Tile 2942: row=0, col=1, row_end=656, col_end=1312
# Transformed Tile 2942: row=0, col=0, row_end=164, col_end=328
# Original Tile 2943: row=0, col=1, row_end=672, col_end=1312
# Transformed Tile 2943: row=0, col=0, row_end=168, col_end=328
# Original Tile 2944: row=0, col=1, row_end=688, col_end=1312
# Transformed Tile 2944: row=0, col=0, row_end=172, col_end=328
# Original Tile 2945: row=0, col=1, row_end=704, col_end=1312
# Transformed Tile 2945: row=0, col=0, row_end=176, col_end=328
# Original Tile 2946: row=0, col=1, row_end=720, col_end=1312
# Transformed Tile 2946: row=0, col=0, row_end=180, col_end=328
# Original Tile 2947: row=0, col=1, row_end=736, col_end=1312
# Transformed Tile 2947: row=0, col=0, row_end=184, col_end=328
# Original Tile 2948: row=0, col=1, row_end=752, col_end=1312
# Transformed Tile 2948: row=0, col=0, row_end=188, col_end=328
# Original Tile 2949: row=0, col=1, row_end=768, col_end=1312
# Transformed Tile 2949: row=0, col=0, row_end=192, col_end=328
# Original Tile 2950: row=0, col=1, row_end=784, col_end=1312
# Transformed Tile 2950: row=0, col=0, row_end=196, col_end=328
# Original Tile 2951: row=0, col=1, row_end=800, col_end=1312
# Transformed Tile 2951: row=0, col=0, row_end=200, col_end=328
# Original Tile 2952: row=0, col=1, row_end=816, col_end=1312
# Transformed Tile 2952: row=0, col=0, row_end=204, col_end=328
# Original Tile 2953: row=0, col=1, row_end=832, col_end=1312
# Transformed Tile 2953: row=0, col=0, row_end=208, col_end=328
# Original Tile 2954: row=0, col=1, row_end=848, col_end=1312
# Transformed Tile 2954: row=0, col=0, row_end=212, col_end=328
# Original Tile 2955: row=0, col=1, row_end=864, col_end=1312
# Transformed Tile 2955: row=0, col=0, row_end=216, col_end=328
# Original Tile 2956: row=0, col=1, row_end=880, col_end=1312
# Transformed Tile 2956: row=0, col=0, row_end=220, col_end=328
# Original Tile 2957: row=0, col=1, row_end=896, col_end=1312
# Transformed Tile 2957: row=0, col=0, row_end=224, col_end=328
# Original Tile 2958: row=0, col=1, row_end=912, col_end=1312
# Transformed Tile 2958: row=0, col=0, row_end=228, col_end=328
# Original Tile 2959: row=0, col=1, row_end=624, col_end=1328
# Transformed Tile 2959: row=0, col=0, row_end=156, col_end=332
# Original Tile 2960: row=0, col=1, row_end=640, col_end=1328
# Transformed Tile 2960: row=0, col=0, row_end=160, col_end=332
# Original Tile 2961: row=0, col=1, row_end=656, col_end=1328
# Transformed Tile 2961: row=0, col=0, row_end=164, col_end=332
# Original Tile 2962: row=0, col=1, row_end=672, col_end=1328
# Transformed Tile 2962: row=0, col=0, row_end=168, col_end=332
# Original Tile 2963: row=0, col=1, row_end=688, col_end=1328
# Transformed Tile 2963: row=0, col=0, row_end=172, col_end=332
# Original Tile 2964: row=0, col=1, row_end=704, col_end=1328
# Transformed Tile 2964: row=0, col=0, row_end=176, col_end=332
# Original Tile 2965: row=0, col=1, row_end=720, col_end=1328
# Transformed Tile 2965: row=0, col=0, row_end=180, col_end=332
# Original Tile 2966: row=0, col=1, row_end=736, col_end=1328
# Transformed Tile 2966: row=0, col=0, row_end=184, col_end=332
# Original Tile 2967: row=0, col=1, row_end=752, col_end=1328
# Transformed Tile 2967: row=0, col=0, row_end=188, col_end=332
# Original Tile 2968: row=0, col=1, row_end=768, col_end=1328
# Transformed Tile 2968: row=0, col=0, row_end=192, col_end=332
# Original Tile 2969: row=0, col=1, row_end=784, col_end=1328
# Transformed Tile 2969: row=0, col=0, row_end=196, col_end=332
# Original Tile 2970: row=0, col=1, row_end=800, col_end=1328
# Transformed Tile 2970: row=0, col=0, row_end=200, col_end=332
# Original Tile 2971: row=0, col=1, row_end=816, col_end=1328
# Transformed Tile 2971: row=0, col=0, row_end=204, col_end=332
# Original Tile 2972: row=0, col=1, row_end=832, col_end=1328
# Transformed Tile 2972: row=0, col=0, row_end=208, col_end=332
# Original Tile 2973: row=0, col=1, row_end=848, col_end=1328
# Transformed Tile 2973: row=0, col=0, row_end=212, col_end=332
# Original Tile 2974: row=0, col=1, row_end=864, col_end=1328
# Transformed Tile 2974: row=0, col=0, row_end=216, col_end=332
# Original Tile 2975: row=0, col=1, row_end=880, col_end=1328
# Transformed Tile 2975: row=0, col=0, row_end=220, col_end=332
# Original Tile 2976: row=0, col=1, row_end=896, col_end=1328
# Transformed Tile 2976: row=0, col=0, row_end=224, col_end=332
# Original Tile 2977: row=0, col=1, row_end=912, col_end=1328
# Transformed Tile 2977: row=0, col=0, row_end=228, col_end=332
# Original Tile 2978: row=0, col=1, row_end=624, col_end=1344
# Transformed Tile 2978: row=0, col=0, row_end=156, col_end=336
# Original Tile 2979: row=0, col=1, row_end=640, col_end=1344
# Transformed Tile 2979: row=0, col=0, row_end=160, col_end=336
# Original Tile 2980: row=0, col=1, row_end=656, col_end=1344
# Transformed Tile 2980: row=0, col=0, row_end=164, col_end=336
# Original Tile 2981: row=0, col=1, row_end=672, col_end=1344
# Transformed Tile 2981: row=0, col=0, row_end=168, col_end=336
# Original Tile 2982: row=0, col=1, row_end=688, col_end=1344
# Transformed Tile 2982: row=0, col=0, row_end=172, col_end=336
# Original Tile 2983: row=0, col=1, row_end=704, col_end=1344
# Transformed Tile 2983: row=0, col=0, row_end=176, col_end=336
# Original Tile 2984: row=0, col=1, row_end=720, col_end=1344
# Transformed Tile 2984: row=0, col=0, row_end=180, col_end=336
# Original Tile 2985: row=0, col=1, row_end=736, col_end=1344
# Transformed Tile 2985: row=0, col=0, row_end=184, col_end=336
# Original Tile 2986: row=0, col=1, row_end=752, col_end=1344
# Transformed Tile 2986: row=0, col=0, row_end=188, col_end=336
# Original Tile 2987: row=0, col=1, row_end=768, col_end=1344
# Transformed Tile 2987: row=0, col=0, row_end=192, col_end=336
# Original Tile 2988: row=0, col=1, row_end=784, col_end=1344
# Transformed Tile 2988: row=0, col=0, row_end=196, col_end=336
# Original Tile 2989: row=0, col=1, row_end=800, col_end=1344
# Transformed Tile 2989: row=0, col=0, row_end=200, col_end=336
# Original Tile 2990: row=0, col=1, row_end=816, col_end=1344
# Transformed Tile 2990: row=0, col=0, row_end=204, col_end=336
# Original Tile 2991: row=0, col=1, row_end=848, col_end=1344
# Transformed Tile 2991: row=0, col=0, row_end=212, col_end=336
# Original Tile 2992: row=0, col=1, row_end=864, col_end=1344
# Transformed Tile 2992: row=0, col=0, row_end=216, col_end=336
# Original Tile 2993: row=0, col=1, row_end=656, col_end=1360
# Transformed Tile 2993: row=0, col=0, row_end=164, col_end=340
# Original Tile 2994: row=0, col=1, row_end=672, col_end=1360
# Transformed Tile 2994: row=0, col=0, row_end=168, col_end=340
# Original Tile 2995: row=0, col=1, row_end=688, col_end=1360
# Transformed Tile 2995: row=0, col=0, row_end=172, col_end=340
# Original Tile 2996: row=0, col=1, row_end=704, col_end=1360
# Transformed Tile 2996: row=0, col=0, row_end=176, col_end=340
# Original Tile 2997: row=0, col=1, row_end=720, col_end=1360
# Transformed Tile 2997: row=0, col=0, row_end=180, col_end=340
# Original Tile 2998: row=0, col=1, row_end=736, col_end=1360
# Transformed Tile 2998: row=0, col=0, row_end=184, col_end=340
# Original Tile 2999: row=0, col=1, row_end=752, col_end=1360
# Transformed Tile 2999: row=0, col=0, row_end=188, col_end=340
# Original Tile 3000: row=0, col=1, row_end=768, col_end=1360
# Transformed Tile 3000: row=0, col=0, row_end=192, col_end=340
# Original Tile 3001: row=0, col=1, row_end=784, col_end=1360
# Transformed Tile 3001: row=0, col=0, row_end=196, col_end=340
# Original Tile 3002: row=0, col=1, row_end=800, col_end=1360
# Transformed Tile 3002: row=0, col=0, row_end=200, col_end=340
# Original Tile 3003: row=0, col=1, row_end=800, col_end=1376
# Transformed Tile 3003: row=0, col=0, row_end=200, col_end=344
# Original Tile 3004: row=0, col=1, row_end=816, col_end=1376
# Transformed Tile 3004: row=0, col=0, row_end=204, col_end=344
# Original Tile 3005: row=0, col=1, row_end=832, col_end=1376
# Transformed Tile 3005: row=0, col=0, row_end=208, col_end=344
# Saved heatmap to GNN_modle_Malignant_5FCross_multiGPU/BM51_categorical_heatmap.png

# %%
tile_coords
# Out:
# array([[   45,     4, 46080,  4096],
#        [   46,     4, 47104,  4096],
#        [   47,     4, 48128,  4096],
#        ...,
#        [   50,    86, 51200, 88064],
#        [   51,    86, 52224, 88064],
#        [   52,    86, 53248, 88064]])
